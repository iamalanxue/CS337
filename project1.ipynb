# %%
import pandas as pd

# %%
gg = pd.read_json('gg2013.json', orient='records')
gg1 = pd.read_json('gg2015.json', orient='records')

# %%
def getUser(x):
    return x['screen_name']
def getID(x):
    return x['id']
def removeHashTags(x):
    
gg['userid'] = gg['user'].apply(lambda x: getID(x))
gg['username'] = gg['user'].apply(lambda x: getUser(x))

gg['text'] = gg['text'].str.lower()

# %%
gg.head()
# Out:
#                                                 text  \
# 0             jlo's dress! #eredcarpet #goldenglobes
# 1  what's making sofia vergara's boobs stay like ...
# 2  rt @fabsugar: kerry washington is everything. ...
# 3     anne hathaway has got me living. #goldenglobes
# 4  jennifer lopez's lace dress? thoughts? #golden...
#
#                                                 user                  id  \
# 0      {'screen_name': 'Dozaaa_xo', 'id': 557374298}  290620657987887104
# 1    {'screen_name': 'theAmberShow', 'id': 14648726}  290620657887219713
# 2        {'screen_name': 'SweetyPW', 'id': 35498686}  290620657828524032
# 3  {'screen_name': '_NicoleEdwards', 'id': 144430...  290620657799159809
# 4  {'screen_name': 'lolaogunnaike', 'id': 134953223}  290620657778188288
#
#          timestamp_ms     userid        username
# 0 2013-01-14 00:45:38  557374298       Dozaaa_xo
# 1 2013-01-14 00:45:38   14648726    theAmberShow
# 2 2013-01-14 00:45:38   35498686        SweetyPW
# 3 2013-01-14 00:45:38  144430208  _NicoleEdwards
# 4 2013-01-14 00:45:38  134953223   lolaogunnaike

# %%
gg1.head()
# Out:
#                                                 text            timestamp_ms  \
# 0  just had to scramble to find a golden globes s... 2015-01-11 22:20:13.011
# 1  RT @ENews: Show us how you're watching the #Go... 2015-01-11 22:25:13.824
# 2  @danaKStew @50ShadesWorldcm @ScarletteDrake Al... 2015-01-11 22:25:13.869
# 3  RT @lisarinna: When your husband tells you tha... 2015-01-11 22:25:13.928
# 4  “@goldenglobes: Creating multiple mini Moët Mo... 2015-01-11 22:25:14.067
#
#                                                 user                  id
# 0        {'id': 19904553, 'screen_name': 'baumbaTz'}  554402424728072192
# 1  {'id': 85020476, 'screen_name': 'devinaaaprilia'}  554403686428864513
# 2  {'id': 1433214326, 'screen_name': 'jamiedornan...  554403686617985024
# 3    {'id': 505974820, 'screen_name': 'WyAttDoRiAn'}  554403686865440769
# 4      {'id': 146599313, 'screen_name': 'Rascal207'}  554403687448469504

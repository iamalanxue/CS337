# %%
# def getUser(x):
#     return x['screen_name']
# def getID(x):
#     return x['id']
# gg['userid'] = gg['user'].apply(lambda x: getID(x))
# gg['username'] = gg['user'].apply(lambda x: getUser(x))

# %%
import pandas as pd
import re
import operator
import string
pd.set_option('display.max_colwidth', 100)

# %%
gg = pd.read_json('gg2013.json', orient='records')
gg1 = pd.read_json('gg2015.json', orient='records')

# %%
copy = gg.copy(deep=True)
copy.head(5)
# Out:
#                                                                                                   text  \
# 0                                                               JLo's dress! #eredcarpet #GoldenGlobes
# 1                 What's making Sofia Vergara's boobs stay like that? Magic? Witchcraft? #GoldenGlobes
# 2  RT @FabSugar: Kerry Washington is EVERYTHING. Dying over her Miu Miu gown! @goldenglobes #golden...
# 3                                                       Anne Hathaway has got me living. #GoldenGlobes
# 4                                                 Jennifer Lopez's lace dress? Thoughts? #GoldenGlobes
#
#                                                  user                  id  \
# 0       {'screen_name': 'Dozaaa_xo', 'id': 557374298}  290620657987887104
# 1     {'screen_name': 'theAmberShow', 'id': 14648726}  290620657887219713
# 2         {'screen_name': 'SweetyPW', 'id': 35498686}  290620657828524032
# 3  {'screen_name': '_NicoleEdwards', 'id': 144430208}  290620657799159809
# 4   {'screen_name': 'lolaogunnaike', 'id': 134953223}  290620657778188288
#
#          timestamp_ms
# 0 2013-01-14 00:45:38
# 1 2013-01-14 00:45:38
# 2 2013-01-14 00:45:38
# 3 2013-01-14 00:45:38
# 4 2013-01-14 00:45:38

# %%
def removePunc(x):
#     new_string = x.translate(str.maketrans('', '', string.punctuation))
    x = re.sub(r'[@#]\w+', '', x) #taking out hashtags and @ 
    x = re.sub(r'(https?:\/\/)?([\da-z\.-]+)\.([a-z\.]{2,6})([\/\w \.-]*)', '', x) #taking out links 
    x = re.sub(r'[!?\.,\'\"]+', '', x) #taking out punctuation i.e ? ! . ' and " 
    return x.strip()
# copy['text'] = copy['text'].str.lower()
copy['text'] = copy['text'].apply(lambda x: removePunc(str(x)))
copy.head()
# Out:
#                                                                 text  \
# 0                                                         JLos dress
# 1  Whats making Sofia Vergaras boobs stay like that Magic Witchcraft
# 2    RT : Kerry Washington is EVERYTHING Dying over her Miu Miu gown
# 3                                    Anne Hathaway has got me living
# 4                                Jennifer Lopezs lace dress Thoughts
#
#                                                  user                  id  \
# 0       {'screen_name': 'Dozaaa_xo', 'id': 557374298}  290620657987887104
# 1     {'screen_name': 'theAmberShow', 'id': 14648726}  290620657887219713
# 2         {'screen_name': 'SweetyPW', 'id': 35498686}  290620657828524032
# 3  {'screen_name': '_NicoleEdwards', 'id': 144430208}  290620657799159809
# 4   {'screen_name': 'lolaogunnaike', 'id': 134953223}  290620657778188288
#
#          timestamp_ms
# 0 2013-01-14 00:45:38
# 1 2013-01-14 00:45:38
# 2 2013-01-14 00:45:38
# 3 2013-01-14 00:45:38
# 4 2013-01-14 00:45:38

# %%
test = list(copy['text'].values)
type(test)
print(len(test))
test
# Out:
# 174643
# ['jlos dress',
#  'whats making sofia vergaras boobs stay like that magic witchcraft',
#  'rt : kerry washington is everything dying over her miu miu gown',
#  'anne hathaway has got me living',
#  'jennifer lopezs lace dress thoughts',
#  'podrán criticar a  de su moda y su maniquere pero jamás podrán poner en tela de juicio su talento',
#  'us weakly',
#  'rt : wait whats that smell (everyone being interviewed by al roker)',
#  'hugh jackman is so awesome',
#  'it was awkward rt : they cut to and then from jlo during the ben affleck interview',
#  'hellen mirren *o*',
#  'jennifer lopezs dress is jaw droppingly amazing',
#  'jessica alba is absolutely flawless omg❤',
#  'werk  stunning  red carpet',
#  'sofia vergara este bueno ella es sofia vergara :)',
#  '“: kate hudsons smile is as infectious as her mothers  ” truth',
#  'why did i just flip out because one of the best people in the world showed up on the',
#  'whats up with this im wearing lace/a tattoo look',
#  'hugh jackman is looking a bit too bronzed orange is not his color',
#  'rt :  is my favorite',
#  'whos that teenage boy standing behind jessica alba hes wearing a strapless',
#  'poor al roker he is just too easy a target',
#  'is gorgeous loved her dress',
#  'mi programa de domingo a la noche va a ser ver los',
#  'rt : if all these beautiful actresses start to make u feel inadequate picture them trying to pee through a spanx hole all night',
#  'my baby leo',
#  'kerry washington is perfect',
#  'it should be illegal to look as good as ewan mcgregor salmon fishing in the yemen was a good movie btw',
#  's nude &amp; sheer = yes jennifer lopezs take on the same trend = oy vey',
#  'ok the moms are shutting it down tonight just caught a glimpse of jlo lawd',
#  'when i grow up i want to be dame helen mirren',
#  'miu miu yes',
#  'actually that corset is perfect for her bad picture the dress is extremely flattering',
#  'kerry washington has been killing it lately loved her django tour dresses and loving her miu miu at the',
#  'natalie morales is gorgeous but dont like the fit of the dress on her',
#  'they are ruining the red “: awkward savannah  awkward ”',
#  'kerry washington looks fabulous',
#  'black dresses with plunging v necklines and high',
#  'im seeing alot of black in the red carpet tonight',
#  'saw george clooney:-) :-)',
#  '',
#  'julianna rancic standing next to short men ryan seacrest next to tall',
#  'rt : oh adele takes our  every time &lt;3',
#  'thats new',
#  'rt : llega el futuro ganador del globo de oro: leonardo dicaprio',
#  'kerry washington is totally showing',
#  'yay another hamm fan',
#  'seacrest asked what ben afflecks kids wrote on his hands  best use of id tell you but id have to kill you',
#  'definetely kates top designers are present in the  tonight of course thanks to the',
#  'rt :  times we wish good luck tonight to rachel weisz nominated for best actress the deep blue sea',
#  'lol - kerry washington tries to show her  bracelet but i was blinded by julianas rock of a ring',
#  'kerry washington in miu miu &amp; prada  &lt;3',
#  'addy: she a princess',
#  'nicole kidman is wearing alexander mcqueen  see more here:',
#  'jennifer lopez looks amazingg',
#  'agree rt : sofia vergara trop marrante et sexy',
#  'hey that was uncle ian',
#  'should be interesting this',
#  'rt : kate hudson y sofia vergara impresionantes guapísimas cada una en su estilo y súper elegantes',
#  'es lindo : tampoco entiendo la fijación con leonardo di caprio :$',
#  'rt : were live blogging the',
#  'rt : nominee  on the red carpet',
#  'youre so right is doesnt get better than this :)',
#  'que guapos son los hombres en traje uff ben viendo',
#  'rt : -  can do no wrong in miu miu',
#  'rt : por la ropa que lleva sienna miller como que harán una película de la sayona',
#  'i never thought that the actual award ceremony had to wait for commercial breaks',
#  'blinded by kerry washingtons miu miu dress and her gorgeous bling we are in love',
#  'damn jlo',
#  'rt : divina sofía vergara pero me gustaría verla arriesgando más',
#  'rt : sofia vergara is sparkling at the  what do you think of the look',
#  'i was just thinking the same thing',
#  'kerry washington in miu miu',
#  'rt : eddie redmayne on the',
#  'jlo looks retarded its sick',
#  'i knew it gotta roll that promotion for',
#  'partiu para ver',
#  'helen mirren   oh god she is such a great actress',
#  'jennifer lawrences dress is ah-maz-ing and i want to be kerry washington when i grow up',
#  'rt : i could listen to adele talk all day long',
#  'rt : rob posing on the carpet',
#  'rt :  is my favorite',
#  'j-lo is stunning -_- ughh',
#  'queria assistir  porém estão assistindo tv e não me deixarão mudar de canal ):',
#  'dicaprio  -need i say more',
#  'yesssssssssssssssssssssssss maam jlo did that',
#  'oh ben affleck you look soo good',
#  'rt : naomi watts slinky backless gown is a zac posen creation is it your favourite of the night so far',
#  'vários vestidos lindo ai sonho',
#  'george clooney will be a hottie at 90 years old i swear that man looks goooood',
#  'kerry washington i cant get over you',
#  'helen mirren looks like me in drag',
#  'rt : ¡kreacher se ha besado con naomi watts',
#  'pretty sure kate hudson is her biggest fan',
#  'rt : marilyn monroe en los golden globes de 1960',
#  'some of those gowns really need a steamer',
#  'whos the guy drinking champagne through a funnel behind helen mirren weirdest photo-bomb ever',
#  'viendo a helen por hitchcock go helen',
#  'rt :  george clooney es definitivamente un viejo churro',
#  'rt : también eva longoria se decanta por el color negro',
#  'listening to ben affleck talk about directing makes us sad',
#  'rt : helen mirren in   2013',
#  'la gente hablando de los  y yo aquí hablando de staphylococcus klebsiella esporlucación ☹',
#  'uh who did helen mirrens hair',
#  'rt : its been 13 years since i stood on a red carpet with denzel washington  remember the titans i do',
#  'rt :  on the',
#  'kerry',
#  'en vista que mi compañero de travesuras ya duerme veré los',
#  'bol de céréales tapis rouge et bonheur',
#  'kerry washington killin it again',
#  'awe thats a movie i forgot to see in 2012 hitchcock i knew it would be brilliant',
#  'judging by her face jennifer lopez is confusing the  red carpet with a playboy photo shoot',
#  'oh leo be still my heart',
#  'if i didnt have midterms id probably be watching the  red carpet right now bummer',
#  'rt : taylor swift looks like a goddess tonight',
#  'awards season is all about dresses of course but admit it ladies its about the hot male actors in tuxes too isnt 😍',
#  'marion and zooey killed it',
#  'im glad death is making an appearance tonight\noh thats helen mirren',
#  'you look incredible',
#  'i told yall  was going to out dress everyone',
#  '&amp; s daughters write on bens hands 4 good',
#  'karen e gary estão mesmo no golden globe awards com a jen',
#  'i will marry you',
#  'rt : seacrest tells kate hudson quentin tarantino says he watches your films on airplanes and cries whenever he sees them',
#  'i will never tire of loving how much hugh jackman loves his wife',
#  '“: oscar winner actress anjelica huston just arrived to the red carpet  in ”// genio amigo',
#  'sienna millers dress by erdem is a fab 60s style dress',
#  'no me gusta “: anne hathaway   ”',
#  'is so gorgeous holy cow',
#  'sofia vergara es como boom me encanta',
#  'seacrest asked what ben afflecks kids wrote on his hands  best use of id tell you but id have to kill you',
#  'ben affleck is looking hot love the beard',
#  'rt : rt “: nicole kidman in alexander mcqueen  2013  ”',
#  'jessica alba is sooo overrated',
#  'helen mirrer bella como siempre la adoro',
#  'rt : rt if you dont care about the  (1/2)',
#  '“: 3 hours of hair and makeup later and im ready to hit the  red carpet ”wow',
#  'me dan ganas de llorar cuando veo el cuerpo de jennifer lópez o_o   aunque sería bueno que cerrara la boca xd',
#  'rt : rob posing on the carpet',
#  'rt : los  cumplen esta edición 70 años aproximadamente el mismo número (70) de novias que hemos visto a george clooney',
#  'il est prodigieux dans tout ce quil fait pour moi',
#  'soooo many lush dresses',
#  'i thought this was a  post haha',
#  'so hard to smile walk wave and look gorgeous',
#  'finally some glam  looking sooooo hot',
#  'all these hot men in  hot',
#  'plunging necklines everywhere',
#  'jennifer lawrence’s boobs look weird in that dress which is tragic because she’s amazing',
#  'hey olivia',
#  'jennifer lopez shit damn damn',
#  'kerry washington is tiny  also gorgeous',
#  'looking forward to seeing what  hits the runway with',
#  'helen mirren = chicos extreme',
#  'you look great at the  tonight',
#  'ive seen a grand total of one nominated film so not caring about awards season ill just let  entertain me',
#  '',
#  'hello rt “: 3 hours of hair and makeup later and im ready to hit the  red carpet ”',
#  'hugh jackman leonardo dicaprio 😍',
#  'se vc quiser postar algo menos inútil no twtr espere o  acabar pfavor não posso perder esse evento',
#  'best dress of the night jennifer',
#  'rt : robert pattinson in  made to order signoria tuxedo mtc  ://',
#  'mucho encaje vestidos con falda tipo sirena y color negro eso es lo que he visto en la alfombra roja de los',
#  'i like how hugh jackmans wife is normal age &amp; size she must actually eat bread &amp; stuff like the rest of us normal folk',
#  'tenho preguiça do ben affleck só pq ele já namorou a chatinha da jennifer lopez',
#  'rt : ok viendi goldenglobes',
#  'rt : 3 hours of hair and makeup later and im ready to hit the  red carpet',
#  'rachel weisz your dress aint right for these awards',
#  'why is helen mirrens hair blond',
#  'hello you rt “: eddie redmayne on the   ”',
#  'viendo los  por pura referencia cabe destacar que no he visto la mayoría de los filmes nominados',
#  'leonardo dicaprio will always be my favorite actor',
#  'rt : i’m wearing fuchi*',
#  '¡qué feo vestido trae helen mirren :s',
#  'kerry washington can i be you',
#  'alot of black dresses on the red carpet',
#  'rt : ya está en nuestro site el vídeo de  que habéis visto en canal+',
#  'i want to listen to a long conversation between adele and sacha baron cohen',
#  'kristen wiig couldnt have found a dress that makes her boobs look smaller',
#  'kerry washintong necesita aunque sea unos tacones más altos para no ser aplastada en la alfombra',
#  'what  channel is ryan seacrest on',
#  'rt : ¿dónde está matt bomer en los  ¿dónde',
#  'con  mirando',
#  'looks stunning',
#  '',
#  'hey tom cruise this is matt lauer being glib',
#  'helen mirren better werk she is pulling off a light purple smokey eye flirty curls and a banging dress',
#  'rt : i live for award shows',
#  ': leonardo di caprio est+a en la alfombra roja de los',
#  'im just surpised helen mirren isnt naked',
#  'rt : taylor swift in   2013',
#  '',
#  'helen mirren what are you wearing',
#  'rt : kate hudson looks beyond chíc  love it',
#  'plunging neckline overload tonight',
#  'rt :  no sponsor for mani cam on     you need a better ad sales team $$opps',
#  '¿halle berry haciéndole el coco a angelina jolie enseñañndo la pierna',
#  'denzel washington qué grandisimo que es por favor',
#  'she’s so thin rt : anne hathaway',
#  'rt : which channel is just the live feed of a camera pointing at jennifer lawrence',
#  'rt : ya no sé ni por quien gritar ¿por quién coño grito hay demasiada gente guay',
#  'oohlala kate hudson kills it in black and gold',
#  'rt : :) rt : this guy  is a latecomer on the  carpet',
#  'how did i not realize hugh jackman was australian until right this very moment',
#  'anne hathaway chanel prechus prechus',
#  'rt :  looks gorgeous in donna karan at the :',
#  'adele se veía hermosa que voz',
#  'anne hathaway good lord of mercy mammansnnanansnsn',
#  'hugh jackman compared singing in front of a camera crew for  to doing a nude scene in front of 50 people oookay',
#  'they look spectacular in these dresses but theyre neither warm nor comfortable wise words from dame helen mirren',
#  'how long until lower third television graphics on the red carpet shows have all the designer names pre-loaded for each star',
#  'cant get enough of kerry washingtons choppy haircut',
#  'oh anne thats too old of a look for',
#  'rt : gretchen weiners: stop trying to make the mani-cam happen',
#  'no entiendo la gracia de la',
#  'amo a anne hathaway se ve hermosa con cabello corto :)',
#  'ill tell ya whos wearing on me: actors at the  rt  apparently were all sharing what were wearing',
#  ': kate hudson não come nada sólido desde o último',
#  'anne hathaway looks gorgeous but ive liked her other choices much better',
#  'rt : these  red carpet interviews are so saccharine need someone to say: hi your movie sucked and your dress is awful',
#  'leo ❤❤❤❤❤',
#  'why does jlo make that face u know the i think im so sexy kissy face  but that dress hmmm',
#  'rt : robert pattinson in  made to order signoria tuxedo mtc  ://',
#  'viendo   ♥',
#  'dame helen mirren is my spirit animal we also dated in the late 90s',
#  'rt : on my way to the  break a leg tina and amy',
#  'kerry washington is so gorgeous love her miu miu dress',
#  'such a doll but someone shouldve combed her weave out of her face more',
#  'jennifer lopez just shut it down in nude lace',
#  'yes',
#  'i wanna borrow kerry washingtons dress for my rehearsal dinner',
#  'rt : robert pattinson in  made to order signoria tuxedo mtc  ://',
#  'the one consistent line throughout my entire life is the raging crush i have on ewan mcgregor',
#  'richard gere needs better hair he just does',
#  'sofia vergara wow',
#  'yay  is there',
#  'anne hathaway you are stunning as always',
#  'loving kerry washingtons looks tonight she looks lovely and vintage and simply gorgeous',
#  'helen mirrens dress looks like spandex yuck',
#  'rt : so that was weird live from the red carpet at the  lea michele and heidi klum were rushed along with no time to',
#  'rt : kate hudson in black she looks smoking hot',
#  'rt : julia louis-dreyfus in   2013',
#  'eu também rt  eu detesto ben affleck',
#  'dont like anne hathaways dress - it looks like the top half is too big for her',
#  'rt : i just won the golden globe for acting (like i give a shit about whatever my wife is talking about)',
#  'rt : ewan mcgregor de barba obi-wan kenobi feelings',
#  'im absolutely loving the   red carpet coverage so many glam looks',
#  'does kerry washington think shes 12 ditch the bangs',
#  'loving anne hathaway in chanel',
#  'aahh anne hathaway and jessica albaaa',
#  'oooh jlo',
#  'is anne hathaway  why the maternity top',
#  'i am missing  so sad :(',
#  'rt : me encanta kerry washington en',
#  'no words nicole kidman in alexander mcqueen',
#  'oh jlo no',
#  '',
#  '“: best of the  : michelle dockery ”',
#  'who is that dude taking swigs of champagne behind helen mirren',
#  'loving kate hudsons dress wow',
#  'rt : watch out angies right leg -  thanks to this dress from',
#  'rt : being a guy its hard to start jokes about  when theres 🏈on tv still even harder when theres so many pretty dresses 💃',
#  'is literally giving me my whole life right now she looks beyond fab  org',
#  'i like marion cotillard on the red carpet even her hair just really pretty :)',
#  'join us at the commercial break',
#  'if only your book were moving d have a very good chance of winning',
#  'rt : más rojo: marion cotillard usa un custom made christian dior diseñado por raf simons para la ocasión se ve increíble',
#  'rt : i heart kerry washington no',
#  'rt : er reunion with george clooney and julianna marguiles',
#  'loving kate hudsons dress',
#  'the things people wear sometimes',
#  'rt : nos últimos 20 anos apenas 2 séries ganharam prêmio melhor drama por mais de uma vez consecutiva: arquivo x e mad men',
#  'sofía vergara quitando el hipo una vez más me encanta',
#  'jon bon jovi is such a dilf',
#  'rt :  suits up for the :',
#  'im very disappointed  is getting better on her accent how am i supposed to copy it from her to attract more men',
#  'my hot cup of organic tea and watching the',
#  'anne hathaway looks beautiful as always',
#  'at work catch all you need to know about todays  here',
#  '¿en qué congelador se ha metido denzel washington ¡está igual que hace 2 decadas',
#  'the guy drinking right out of the bottle behind helen mirren is such a class act 😒',
#  'rt : dont like kerry washingtons hair or dress',
#  'rt : i could listen to sofia vergara say lorraine schwartz diamonds for hours on end it just never gets old',
#  'anne hathaway in white looks absolutely stunning',
#  'i dont know who half of these people are and they all look alike i guess im old',
#  'agora vou ver os',
#  'anne hathaway cute dress',
#  'rt : best of the  : zooey deschanel',
#  'sofia vergara delgadisima en un vestigo negro va va bom',
#  'anne hathaway in white house black market tube top im not sold',
#  'rt : just saw my girl  on the  red carpet yes u have arrived😘',
#  'kerry washington',
#  'what is with these separate tops noo',
#  'i love ewan mcgregor so hard look at his hair he has great hair his wife is unnecessary',
#  'adele on the',
#  'helen mirren makes me unafraid of growing older',
#  'orgulho da minha amy adams &lt;3',
#  'worst dressed so far for me… anne hathaway and sienna miller wtf were they thinking',
#  'rt : ¿alguien se tirará un peo en la alfombra roja de los',
#  'looooove anne hathaways dress hair get-up',
#  'theres a guy drinking an entire wine bottle on the red carpet',
#  'esta noche es ://',
#  'esta',
#  'can you please follow me i love you &lt;33',
#  'leo sempre elegante sempre',
#  'melhor atriz torço pra hushpuppy ou velhinha  com avc as outras não sabem se vestir',
#  'yes he is “: clooney cant get his jacket closed  i wonder whats up with that  hes so beautiful  ”',
#  'has girded her loins just fyi',
#  'my favourite of the   is julianne moore in tom ford gorgeous',
#  'only watching the  if someone trips and falls on the red carpet why this never happen or is it that they never show it',
#  'rt : ewaaaaan ♥',
#  'rt : ai papi ariba ariba ai modeeerrn familia blah blah tits blah ai -sofia vergara',
#  'helen mirren de caligula a la reina isabel ahora es la señora de hitchcok',
#  'kerry washington is gorgeous',
#  'anne hathaway is looking very audrey this evening especially with the hair and overall gamine-ness',
#  'agreed:  may have gone for comfort  really good on her',
#  'lucy liu is a bad mamma jamma',
#  'the lovely  on the red carpet of the',
#  'rt : kristen and dax -- exclusive pose for tvline',
#  'only ricky gervais wd say that mt :  red carpet interviews saccharineyour movie sucked &amp; your dress is awful',
#  'jennifer lopez looks amazing',
#  'she does i also think sofia vergara is gorgeous tho her dress not so much:-)',
#  'leonardo dicaprio nossa so gente perfeitaaa *-*',
#  'were taking a break from the work of the weekend to watch poehler &amp; fey whos with us',
#  'ah leo-- *swoon* i love you',
#  'my favorite',
#  'luvd kate hudsons look  shes just gorgeous  period',
#  'has helen mirren had work done',
#  'i do wanna be one of the afflecks',
#  'rt : its been 13 years since i stood on a red carpet with denzel washington  remember the titans i do',
#  'rt : loving the mani cam on e haha',
#  'kerry washingtons miu miu dress is fantastic as is scandal',
#  'rt : best of the  : zooey deschanel',
#  'rt : if all these beautiful actresses start to make u feel inadequate picture them trying to pee through a spanx hole all night',
#  'im loving that blue',
#  'rt : mel gibson on the',
#  'looking forward to watching tina fey and amy poehler host the',
#  'anne hathaway great dress hair not so much',
#  'dude behind helen mirren chugging down champagne from the bottle using a plastic funnel',
#  'rt : golden globes or homework',
#  'kerry washingtons hair is looking phenomenal love her hair/jewelry/dress are perfect complements to eachother',
#  'rt : can kerry washington be nominated for an emmy for acting flattered that fashion police named her best dressed of the week',
#  'i will always love ben affleck',
#  'seacrest: what are you wearing clooney: i believe its some sort of cloth',
#  'nice one  aawrgfh rt  best of the  : zooey deschanel',
#  'a lot of simple hair',
#  'why does the ‘dress-tilt’ camera keep going dark when it tilts to the dress',
#  '“: marion cotillard in christian   2013 ” lo quiero',
#  'always so festive rt :  manicure movie camera and film strip by redcarpetman',
#  'leonardo dicaprio 😘😍😏',
#  'totes in an amazing way “:  does she look just like her mom 30 years ago whats old is new ”',
#  'jlo looks great she is clutching on to youths necklace with an iron grip',
#  'too busy for the  this go around somebody tweet me if cumberbatch wins',
#  'i love leonardo dicaprio will his dark hair makes his baby blues stand out sexy 😍',
#  'yep i think  is pregnant with that two piece dress',
#  'jessica chastain is gorgeous',
#  'rt : 5 outrageous  moments',
#  'ok seeing jessica chastain for the first time love the color on her hate the hair wtf',
#  'rt : kerry washintong necesita aunque sea unos tacones más altos para no ser aplastada en la alfombra',
#  'donne sempre svestite uomini troppo vestiti',
#  'rt   look tonight esp her  earrings  love it',
#  'rt : kristen bells maternity dress',
#  'more like dayamn helen mirren',
#  'amo muito o leonardo dicaprio jesus',
#  'ante hathaway le pongas el peinado que le pongas se rape al cero o no esta bellísima',
#  'neyse ben altin kureyi izleyeyim pardon bradley cooper i mi demem gerekirdi :/',
#  '60s is a main  trend @ the  as seen with : big eyebrows &amp; flicked eyeliner',
#  'rt : hearing selena gomez and vanessa hudgens are coming to the',
#  'anne hatawhay &lt;333',
#  'sooo much black on the',
#  'rt : most pressing issue of the night should those of us using the  hashtag switch to the trending  decisions',
#  'impresionante jessica chastain',
#  'hellooooo leo',
#  'why is',
#  'more like jessica chestine',
#  'jlo=smokeshow',
#  'leo dicaprio &lt;3',
#  'rt : two primary reasons for tuning into the  this eve: (1) tina fey and (2) amy poehler been waiting for',
#  'rt : ah finally my favorite dress (miu miu) on kerry washington also loving the blue shadow',
#  'rt : jennifer lawrence getting ready for the',
#  'oh hayyy leo *flips hair*',
#  'rt : helen mirren looks fabulous',
#  'anne hathaway wow she is radiant',
#  'vtv rt tves rt  televen rt: venevision rt  ¿en que canal dan los',
#  'rt : julianne moore always',
#  'rt : robert pattinson has arrived at the  check him out:',
#  'oh leonardo dicaprio i will never stop loving you',
#  'guy chugging moët straight from the bottle behind helen mirrens head as shes being interviewed i salute you',
#  'just started watching scandal didnt know kerry washington before that i like her and her little lisp',
#  'rt : eeeemiiilyyyy',
#  'rt : anne looks amazing',
#  'rt : angelina just arrived',
#  '',
#  'y su peinado me encanta *-*',
#  '¡¡¡leonardo dicaprio tiene entradas',
#  'ame el vestido de sofia vergara♥',
#  'rt : its been 13 years since i stood on a red carpet with denzel washington  remember the titans i do',
#  'leooooo there you are',
#  'que peo con los mamaguebos estos haciendole rt a toda mierda sobre los',
#  'matt lauer looks like the guy holding his girlfriends purse at the bar like youre getting paid man',
#  'leonardo di caprio ha estado de dieta y con infusiones de cola de caballo',
#  'anne hathaway in a white chanel  on',
#  'i dont like anne hathaways rig-out at all at all',
#  'helen mirren girded her loins  im not providing any context',
#  'leo doin his handsome thang',
#  'rt : and now the girl version of studying distractions: red carpet &gt; football',
#  'helen mirren dipçik gibi',
#  'kinda liking anne hathaway in white',
#  'im literally crying because of the perfection that is lea michele screaming she looks perfect',
#  'rt : adele and taylor swift are only a year apart crazy different maturity levels lol',
#  'jessica chastains hair',
#  'hey leo ^^',
#  'de las 2 latinas que he visto ahorita en  definitivamente se ve muchisimo mejor',
#  'rt : i think al roker just spoiled part of silver linings playbook for me  (legit wrote soiled at first i cant you guys)',
#  'goldenglobess photo',
#  'so much fashion im so inspired 👗👠👛💄👔',
#  'rt : we heart you so much adele',
#  'aniñe hathaway más bella imposible en color blanco asombrosa',
#  'please remember  at',
#  'jessica chastain looks lovely that dress yes im sayin s meryl streep',
#  'gorgeous',
#  'i just loooove  está bella en ese look de hoy',
#  'rt : tune to  right now for all their   coverage and keep checking (cont)',
#  'jazzy hands hathaway finally decided to show',
#  'jessica chastain humilhando na lindeza',
#  'giuliana: rad or bad',
#  'leonardo dicapriooh dios que ojosque rostroque hombre',
#  'oh man hugh jackman 😘',
#  'rt : después de dar todo un discurso en inglés en la alfombra roja de los  sofía vergara se despide con un gracias',
#  'lol rt  ok so ive just seen es mani cam - i clearly live in another universe this is hilarious',
#  '“: s my favorite thus far  ” agree',
#  'leooooo',
#  'where are the divas: glenn meryl judi maggie etc',
#  'dicaprio looking sharp at the',
#  'it seems as though  is wearing her costume from excalibur to the  tonightb',
#  'rt : lo que más me gusta de sofía vergara es su acento cuando habla inglés lo hace a propósito oki',
#  'loving the fashion at the',
#  'rt : ftw jeremy renner just photobombed a random couple taking a pic on the red carpet',
#  'qué tal qué impresiones tienen de la alfombra roja de los',
#  'watching paranorman instead of the',
#  'again  in  is heavenly',
#  'que hermosaaaa esta sofia vergara',
#  'hugh jackman so freaking hot handsome perfect on the red',
#  'i am a huge fan of textured',
#  'rt : who else loved the george clooney and julianna margulies er reunion before',
#  ':   desde la bella ciudad de los altos xelaju/un abrazo a la hermosa xela',
#  'leonardo dicaprio get out of here',
#  'watching the   drinking hot tea eating skittles and hanging out with my puppy',
#  'i bet helen mirren would be suuuuuper fucking intimidating in person',
#  'rt : its been 13 years since i stood on a red carpet with denzel washington  remember the titans i do',
#  'rt :',
#  'running to the grocery store so i can watch lots of',
#  'rt : ya tengo los pañales puestos para cuando aparezca ryan gosling',
#  'who let mel gibson in',
#  'rt : adele at the golden globes looking fucking stunning',
#  'wait what rt : mel gibson on the',
#  'and what is',
#  'wtf “: ¿alguien se tirará un peo en la alfombra roja de los ”',
#  '¿yoshiki en los',
#  'omg leonardo dicaprio❤❤',
#  'if leo could wear a tux everyday  he still wouldnt get an oscar nomination',
#  'ah they just showed leo',
#  '¡enfoquen a taylor',
#  'is looking gorgeous as hell today  👌',
#  'leonardo dicaprio&lt;333',
#  'rt : 3 hours of hair and makeup later and im ready to hit the  red carpet',
#  'comentando los   mejores presentadores no hay',
#  'rt :  suits up for the :',
#  'anne',
#  'rt : robert pattinson in  made to order signoria tuxedo mtc  ://',
#  'rt :  is my favorite',
#  'looks amazing on the red carpet pregnant looks amazing on her',
#  'wait i take that back nicole kidmans dress 😍😍😍',
#  'i love hugh jackman',
#  'agreed  plus  the nude lace blech',
#  'what part of twitter is the positive part ive never seen it',
#  'but wheres nancy',
#  'daniel day lewis is killing it as jessica chastain tonight',
#  'cómo tiene acceso esa gente que grita a la alfombra roja    inviten',
#  'leooonaarrrdo dicapprio',
#  'fatal anne hathaway',
#  'adele is so flawless',
#  'leo you dont need a beard though youre good',
#  'im in india and about to watch the  whuck',
#  'rt : ben affleck mejora con los años *babas*',
#  'i love anne hathaways hair she looks awesome',
#  'i know its a crazy night but get that hashtag right',
#  'my hubby has never looked better fight me on this try',
#  'damn leo lookin sharp as fuck',
#  'rt : lincoln should take notes from django unchained if youre gonna do a movie about slavery include jamie foxxs perineum',
#  'rt : loving the mani cam on e haha',
#  'in love “: another red dress on the red carpet how does jennifer lawrences dior gown compare  ”',
#  'jennifer being interviewed at the',
#  'rt : dear everyone: when tweeting about the show make sure you use the hashtag  that way its easier to mute you',
#  'fashion: stars arrive on the red carpet',
#  'hate it but she can do no wrong “: here is marion cotillard in   ”',
#  'rob :) rt :',
#  'oh hey leo',
#  'rt : anne hathaway *hair flick head turn* * booom instantly fallen in love',
#  'jessica chastain se ve sexy pero ese vestido no me gusta casi',
#  'rt : nicole kidman in alexander mcqueen  2013',
#  'que vestido horroroso',
#  ':)',
#  'denzel is looking old which is actually heartening and kinda hot',
#  'kristen bell and her baby bump are so cute',
#  'is anyone else getting motion sickness from the speed of es glam cam  slow that crap down',
#  'sofia vergara parece que tá sempre com o mesmo vestido linda mas parece mais do mesmo',
#  'i had a flashback to titanic premiere you dont age man',
#  'oh christ here comes hathaway',
#  'rt : nominee  on the red carpet',
#  'looks amazing tonight',
#  'anyone remember tila tequila  because thats who i just mistook jennifer lopez for',
#  'kristin mon kate hudson very classy  anne hathaway look okay not obsessed with it',
#  'adele tá lindaaaaa',
#  'anne hathaway no on the pixie cut and no on the white two-piece-looking dress',
#  '15 minutes to get these kids home so i can watch to',
#  'rt : la hijita de denzel washington es toda una tarajalla',
#  'denzel y la ¿hija',
#  'rt : kate hudson: i decided to go for comfort right because when we want to be comfortable we throw on a gown too',
#  'i guess i picked the right anniv lol',
#  'en unas horas mas los',
#  'anne hathaway pregnant survey says: globes dress suggests pregnant',
#  '',
#  'yay were both rooting for kathryn bigelow',
#  'rt :  you are perfect',
#  'anne hathaway hermosa con el cabello corto',
#  '“:that chick from downton abbey is also one of my faves on the red carpet thus far”',
#  'this red head prolly took a zero dark thirty inch cock in her ass',
#  'way to go  split screen ben affleck with jlo',
#  '',
#  'rt : jo ann worley is resplendent in a taffeta firefighters jacket; charles bronson in a kilt and hairshirt',
#  'rt : finally spotted lea michele in a sparkly white dress with a high split (of course)',
#  'que levante la mano el que no esta criticando según su gusto los diseños de los',
#  'rt : s sarah paulson has arrived on the red carpet',
#  'aguardando o  adoroooooo',
#  'time everyone',
#  '',
#  'kerry washington always looks great but i do wish shed gone for a bigger bolder look because she is such a style icon',
#  'rt : jon bon jovi en la alfombra de los',
#  'rt : its been 13 years since i stood on a red carpet with denzel washington  remember the titans i do',
#  'lol thought it was his wife',
#  'leonardo dicaprio is looking super suave on the   tonight',
#  'julianne mooremichelle dockerynaomi watts stunning totalessssssssssss',
#  'rt : informações que a selena se perdeu no meio do caminho e perguntou onde era o  para um pedestre e ele desmaiou',
#  'leonardo dicaprio &gt;&gt;&gt;&gt;&gt;&gt;&gt;&gt; adios my eyes cause he shine like a diamonds',
#  'sofia vergara como siempre una diosa',
#  'rt : s sarah paulson has arrived on the red carpet',
#  'the best phrase i read today was dicaprio apologist and i am one of those apologists',
#  'she still looks gorgeous rt : look at halle berry',
#  'rt : marilyn monroe en los golden globes de 1960',
#  'agree “: wow nicole kidman actually looks amazing in alexander mcqueen #  ”',
#  'rt : kerry is getting ready to take the red carpet  tune into  now -kws krew',
#  'this years theme for mens  fashion: bow ties are cool',
#  'rt : photos from the red carpet',
#  'jessica chastain looks like the mozilla firefox in calvin klein &amp; harry winston',
#  'rt : artistas como kate hudson solo quieren pasarla bien en estos galardones',
#  'rt : mel gibson on the',
#  'rt : its been 13 years since i stood on a red carpet with denzel washington  remember the titans i do',
#  'rt : loving the mani cam on e haha',
#  'it was a great run  but now its on to the',
#  'rt : deve ser constrangedor para a taylor swift ir aos  tantos ex-namorados no mesmo sítio é como o lust para algumas pessoas',
#  'muh gurl kerry washington 👌',
#  'does denzel ever age',
#  'she always does so lovely',
#  'whoever is standing behind helen mirren is drinking moet straight from the bottle through a moët branded spout',
#  'rt : here is jessica chastain wearing a custom  seafoam halter gown',
#  'leonardo dicaprio siempre nominado siempre solo en las premiaciónes',
#  'sofia vergara picks a silhouette and sticks with it beautiful but she can pull off other looks   xoxo',
#  'os amigos do site os cinéfilos divulgou a lista completa para quem deseja acompanhar',
#  'en verdad que me tiene impresionado',
#  'all of these celebrities in these gorgeous dresses😍😍😍',
#  'anne hathaways dress is les miserables',
#  'bradley cooper 😍',
#  'aviso que voy a tuitear mucho en estos momentos',
#  'solo a sofia vergara le queda espectacular el negrooo &lt;3 *-*',
#  'sofia vergara all sparkly in black 😍 apparently she loves our black  too',
#  'anne hathaway you would like amazing if your dress had come in one',
#  'anne hathaway icono de la moda mujer hermosa talentosa pero unos kilitos mas la harian ver mejor',
#  'jessica chastain on right',
#  'gostei do vestido da sofia vergara acho que é o meu favorito até agora mas nada demais tb',
#  'leo deserves every award',
#  'jessica chastain … que mujer preciosa',
#  'adele on the',
#  'getting ready to try to relax for the night after a busy weekend',
#  'omg graaaaciaaaas love :  ahí va',
#  'how did i miss eddie redmayne',
#  'halle berry looking like the angels lick her face every morning skin is tight and wrinkle-less i am',
#  'rt :  shares behind the scenes photos with   and more at the',
#  '',
#  'rt :',
#  'sofia vergera could do more with her hair',
#  'que estupenda',
#  '“: you have to hand it to the golden globes - completely s must-see tv ”&gt;tellement',
#  'rt : its almost painful to look at kerry washington because shes that gorgeous',
#  ': who am i wearing starbucks spilled all down my front  thats awesome',
#  'short hair rules anne hathaway',
#  'i am bored enough i may actually watch the award show',
#  'mhmmmm denzel ;)',
#  'bu geceyide  ile kurtardık gibi duruyor;) ama keşke seslendirmeyi başkası yapsaydı',
#  'whoever dressed jessica chastain/ did her hair snaked her her',
#  'dont like him since i hears what a prejudiced person he is',
#  'i think anne hathaway is prego',
#  'rt : un  con brillantes aplicaciones es la elección de kerry washington',
#  'denzels daughter needs a',
#  'siii auque debo decir que no me encantó su traje blanco',
#  'kate hudson looks fierce ughhh  red carpet live',
#  'are those christmas tree lights denzel',
#  'cute steven spielberg entered the ballroom clutching kate capshaws hand',
#  'i feel like ill be the only sober person live tweeting the',
#  'just saw  with his heisenberg shades on chatting with  aha',
#  'did they really just toss to natalie to have her toss to break that’s super awkward',
#  'denzel fue con teresa izquierdo',
#  'snore red carpet',
#  'lmao “: hey nbc shouldve gotten a mani cam e wins this round ”',
#  'unlulere bu sene nolmus bole cok guzel kiyafetler var  da saskinim :) tercihler gayet basarili',
#  'yup rt : latinas are killing the carpet this evening',
#  'here is marion cotillard in',
#  'omg *-* kate hudson looks sooooo hot at the',
#  'that awkward silence heard round the world during awards s wife',
#  'amo a denzel washington el hombre más guapo del mundo',
#  'rt : somebody please double check where damian lewis parked tonight',
#  'rt : rt : anne hathaway   || un niño',
#  'whos taller: kerry washington or peter dinklage',
#  'kate hudson looked great in that black dress she always',
#  'making me weak at my knees handsome as ever',
#  'rt : hey nbc shouldve gotten a mani cam e wins this round',
#  '“: leooooooooooooooooo ”',
#  'je suis habillé en calvin klein hihihi osef',
#  'rt : eva longoria en los  muuucho negro en esta red carpet',
#  'well that was awkward seacrest',
#  'rt : another pic of rob',
#  'rt : sofía vergara se rajó de linda hoy &lt;3',
#  'rt : on the carpet',
#  'kerry washington looks gorgeous but she looked better at the inaugural ball :)',
#  'and his daughter how wonderful',
#  'i remember when i used to get excited for a ben affleck sighting and now when hes on i run to the kitchen for a',
#  'jon hamm always hot',
#  'rt : loving my   mani at the stylecoalition  viewing party',
#  'track pants by  t-shirt by',
#  'jessica chastain luce un calvin klein con pronunciado escote  d',
#  ': al roker looks like if shrek and donkey had a baby   hysterical',
#  'oh ewan *drool*',
#  'rt : leooooooooooooooooo',
#  'is gorgeous as always',
#  'rt : i could listen to adele talk all day long',
#  'leo has arrived its sickening this man does not have an oscar heartbreaking',
#  '🏆🏆🏆🏆🏆',
#  'looking gorgeous on the   😍😍😍',
#  'is absolutely breathtaking',
#  'viendo los trapitos en la alfombra roja de los',
#  'interview leo plz',
#  'fun fact: kerry washington is a huge gaga fan unexpected',
#  'denzel washington looks so proud of his daughter',
#  'rt : rob :) rt :',
#  'rt: viendo a los papi churros  mfff amigui yo tambieeeen :)',
#  'that jawline addio rt : another pic of rob  ”',
#  'rt : let it be known that tonight is about 2 things: dress commentary and the magic that will be amy/tina jokes',
#  'judging by the questions they apparently dont wear inanimate objects at the',
#  'why is everyone wearing a black dress',
#  'rt : ¡espero que a  se le salga una chichi hoy',
#  'a lot of bored faces in beige dresses',
#  'jessica chastain looks like shes trying out for the role of caryatid o_o',
#  'ααααχ ο γλυκουλης ο αφλεκ κανει και παιχνιδακια στην καμερα με την longoria που ειναι η garner γαμω',
#  '- e llive  kerry you look wonderful',
#  'rt : its our hosts tina fey and amy poehler',
#  'gente o denzel washington deu no cerne o homem não',
#  'jessica tá linda demais *-*',
#  'rt : rt if you dont care about the  (1/2)',
#  'is so pretty but she dresses like someone 20 years older than she is',
#  'rt : marilyn monroe en los golden globes de 1960',
#  'loving kerry washington from the front but never a fan when the detailing is only on the front a w/ plain back',
#  'much better ms chastain',
#  'rt : its been 13 years since i stood on a red carpet with denzel washington  remember the titans i do',
#  'rt : here is jennifer lawrence in red  haute couture',
#  '',
#  'rt : my lord  is gorg',
#  'best dressed: jessica chastain jennifer lawrence claire danes &amp;  in kevin dior',
#  'having heated conversations about the  having a fam din din',
#  'love jessica chastains dress',
#  'jessica chastain just arrived in a low cut powder blue halter gown and she looks radiant',
#  'rt : its been 13 years since i stood on a red carpet with denzel washington  remember the titans i do',
#  'if i have to look at anne hathaway constantly is it too much to ask that she wear some nice dresses',
#  'time',
#  'wow keri washington gorgeous',
#  'i think sophia vergara is jessica rabbits long lost daughter',
#  'anne hathaway in strapless chanel oh my heavenly couture im dead',
#  'lazy sunday so glad the  are on bring on the mindless entertainment',
#  'rt : twitter is positive lolololololol giuliana you funny',
#  'rt : no puede ser más simpática  ¡latina tenía que ser para mi es la que más se divierte en los',
#  'you look so gorgeous',
#  'denzel is da man',
#  'leonardo dicaprio ♥',
#  'robert pattinson',
#  'that awkward moment when you confuse denzel washingtons daughter for his wife only at the',
#  'dame helen looks lovely',
#  'nicole kidman is my best dressed so far',
#  'what on earth was jessica chastain thinking with that dress',
#  'looks stunning in her black studded dress and i love jessicas baby blue',
#  'rt : my lord  is gorg',
#  ': more red for the red carpet  marion cotillard in christian dior preciso para la ocasión se ve más joven',
#  'rt : a cerimônia de premiação do globo de ouro começa em instantes confira a cobertura ao vivo:',
#  'rt : on the carpet',
#  'you have won rt  thought golden globes referred to  s  nvm :  n',
#  'denzel washington brings his daughter to the  lovesssss it &lt;3',
#  'i know right rt “: kate hudson goes for comfort-- i wish my comfort looked like that  ”',
#  'jessica chastian looks like her hair mua &amp; stylist werent at all on the same page 3 different looks completly',
#  'jessica chastain favorita por zero dark thirty también le queda raro el vestido en los pechis',
#  'faltan menos de 15 min para que la ceremonia de los  empiece y aun no veo a jeremy renner :(',
#  'rt : hugh jackmanın eşi :(((',
#  'denzel washington with his beautiful daughter too sweet',
#  'rt : are they kidding with the whole everyone on twitter is so nice thing',
#  'rt : seacrest tells kate hudson quentin tarantino says he watches your films on airplanes and cries whenever he sees them',
#  'watching the golden globes w violet and now were talking about cleavage &amp; why some ladies like to show all their goods',
#  'this just in ben affleck is a good looking man',
#  'denzel',
#  'io sono sullo stream di e ma se avete da propormi una diretta meno lobotomizzante fatemi sapere',
#  'rt : s sarah paulson has arrived on the red carpet',
#  'did davids bridal design jessica chastains dress',
#  'quiero foto del vestido de lea ya',
#  'türkiye tt listesine girdi (02:47)',
#  'leonardo dicaprio spotted on the red carpet why so sexy',
#  'need to see jessica alba up close e :) please and thank you',
#  'i  ❤ you mani-cam',
#  'rt : hearing selena gomez and vanessa hudgens are coming to the',
#  'i see a beard on tv oh and hugh jackman has facial hair',
#  'jennifer lopez simple con la boca entreabierta re chic re estrella porno',
#  'denzel your daughters dress smh',
#  'dicaprio cleans up well',
#  'rt : ben aflec se lleva el grooming de la noche &gt;',
#  'rt : we just spotted anne hathaway looking angelic in white she looks amazing the pixie cut suits her so well',
#  'not news   will make you dumb  the worst our country has to offer',
#  'rt : on the carpet',
#  'dont be fooled al roker isnt shorter than the people he is interviewing hes just sitting on a toilet',
#  '“: megan fox to all you haters  ”',
#  'rt : sofia vergara is hot hot',
#  'best looks of the  - jennifer lawrence kate hudson jessica chastain',
#  'rt : wearing a vintage  :)',
#  'rt : yes god  ms kerry washington in this miu miu dress',
#  'ai',
#  'rt : sofia vergara looks like yessica rabbit',
#  'rt : on the carpet',
#  'rt : taylor swift looks like a goddess tonight',
#  'rt : jajajajajajajajajaja es posible rt : ¿alguien se tirará un peo en la alfombra roja de los',
#  'i wish my dad was an award-winning/nominated actor and i could go to events with',
#  'rt : megan fox looking gorgeous in dolce &amp; gabbana at the',
#  'rt : tonights dual hosting duties represent the culmination of a decade of amy and tina partnerships',
#  'minhas apostas:  melhor série drama  melhor ator',
#  'denzel brought his daughter so cute',
#  'rt : kerry washington says she doesnt google herself because its not good for her mental health &amp; she loves twitter love her',
#  'rt : chegou o dicaprio escondam os prêmios~~',
#  'denzel washington nominado por django',
#  'salma hayek lindo',
#  'rt : oh look sofia vergara in a skin tight dress with her tits hoisted up stop the presses',
#  'is so so gorgeous',
#  'omggg rt : another pic of rob',
#  'im watching the 70th annual golden globe awards (6763 others checked-in)',
#  'is one of my favorite times of the year     👠💅👛💄',
#  'rt : my green suede tuxedo pinching a bit here at the velvet rope awards honoring best in crowd control topo gigio + i hosting',
#  'i love  s dress',
#  'rt : taylor swift always looks like she just finished crying because she just finished crying',
#  'rt : jennifer lopez wow',
#  'rt : getting ready for the',
#  'rt : which channel is just the live feed of a camera pointing at jennifer lawrence',
#  'loving all this fashion and jewels on the',
#  'rt : rt : jennifer lawrence being interviewed by e on the  red carpet',
#  'seu lindo os anos se passa e você continua perfeito torcendo por você em melhor ator coadjuvante',
#  '12 minutos para que empiece',
#  'rt : tina fey &amp; amy poehler talk  hosting drinking game',
#  'you could follow  on instagram',
#  'rt : im wearing spanx under my flannel pjs so i can feel like im really there',
#  '',
#  'salma hayek ble ble ble',
#  'rt : en los  promueven las películas que a mi me  pues no han llegado al cine',
#  'sarah hyland y ariel winter del elenco de modern family en la alfombra roja de los',
#  'twitter türkiye gündemine 5 sıradan girdi',
#  'rt : emily blunt in   2013',
#  'chico inviraron a la salma hayek a los',
#  'dress love for kidman and',
#  'parked on the couch snuggled with a blanket and the',
#  'j lo is clearly channelling her inner cher tonight',
#  'beautiful on',
#  'oh jessica that is not flattering',
#  'where are you',
#  'vistas las entrevistas a george clooney hugh jackman y ewan mcgregor ya puedo dormir en paz',
#  'denzel was protecting his daughter there a pre-emptive not my wife my daughter comment for',
#  'rt : torcendo para toda e qualquer categoria que qualquer pessoa de les mis estiver concorrendo especialmente para a anne :p',
#  ': jennifer lopez stunning  🙏😍 yesss',
#  'if denzels daughter leans too far forward shell have a boob accident',
#  'is just the best you look stunning again in the  hope u win tonight 2 thumbs up to you :)',
#  'im in love with sarah paulson stunning',
#  '&lt;3 rt : another pic of rob',
#  ': sofía vergara  stunning',
#  'denzel + his daughter = the cutest couple at the',
#  'quem quiser assistir pela nbc tem esse link chifrin --&gt;',
#  'rt : anne hathaway in chanel haute couture gorgeous  why wear one piece if you can wear 2',
#  'mr pattinson in a gucci tux \nthere is only one',
#  'jugh jackman *--*  thats my man',
#  'kristin wiig : i need that dressssss',
#  'jessica chastain actress du jour wonder what the fuss is all about shes got red hair tho &amp; i absolutely adore red hair',
#  'rt : cuando estas en una ciudad que esta a -10 grados no hay nada más rico que quedarte en cama viendo los',
#  'i wish harry winston was on me tonight he is so hot',
#  'im a huge fan but i really think a bra-less look was a bad',
#  'rt : anne hathaway es una diosa no hay nada que hacer',
#  'kate hudson curvier than usual me likey',
#  '“: hayden panettiere is wearing white roberto cavalli whats your take on her red carpet look  stunning',
#  'salma brought the girls tonight yowza',
#  'denzel aime les formes hahaha',
#  '“: helen mirren in   2013 ” i love that woman',
#  'rt : stacey kiebler doesnt even try anymore shes just like im wearing george clooney',
#  'rt : on the carpet',
#  'rt : these  red carpet interviews are so saccharine need someone to say: hi your movie sucked and your dress is awful',
#  'i love kate hudson kristen',
#  'rt : rt : another pic of rob',
#  'wheres the guy who played fdr  in fdr: american basdass  thats how you know this is fake',
#  'im watching the 70th annual golden globe awards (6853 others checked-in)',
#  'rt : shocker: benedict cumberbatch says hes never met the film  robert downey jr',
#  'legolas',
#  'rules my tl :d',
#  'kerry washington says she doesnt google herself because its not good for her mental health &amp; she loves twitter love her',
#  'rt : anne hathaway in chanel haute couture gorgeous  why wear one piece if you can wear 2',
#  'wait till you see helen mirren from the  tonight babe',
#  'por qué leonardo dicaprio no envejece',
#  'im using three different live streams right now',
#  'rt : no puede ser más simpática  ¡latina tenía que ser para mi es la que más se divierte en los',
#  'rt : anne hathaway',
#  'kate hudson s beautiful and sexy',
#  'im sorry but the latinas are showing out',
#  'exactly “: lets consider mcqueen the winner and call it a night eh    ”',
#  'o rojo o negro',
#  'and now i want jessica chastains 40s glamour hair and her',
#  'im watching the 70th annual golden globe awards (6853 others checked-in)',
#  'is the cutest man alive let his daughters write on his hands for a second time',
#  'lea michele in elie saab',
#  'rt : adele has stunning eyes',
#  'leo dicaprio is looking fine tonight',
#  ': another pic of rob',
#  'sorprendentemente la amiga salma no luce tan mal',
#  'rt : denzel washington looks great as usual',
#  'rt : okay i know half of you are going to freak s dress',
#  'rt : kristen and dax -- exclusive pose for tvline',
#  'rt : lets hope for a kevin costner win for',
#  'ben affleck still looks so hot',
#  'rt : mais uma',
#  'rt : heres a blurry rob pattinson',
#  'rt : i really really really hope adele wins a globe tonight she looks gorg in',
#  'golden globe has instagram follow goldenglobes i saw it',
#  'im celebrating the glamour of the golden globes by wearing sweats eating popcorn and drinking shiner',
#  'rt : jodie foster trending at  on twitter right now pre-lifetime achievement award at  red carpet pic:',
#  'i will post a free stream for the  in 13 mins cannot wait',
#  'salma hayek snoozefest',
#  'salma hayek ha revivido',
#  'and yet i admire her for saying shes warm and comfortable shes probably the only one',
#  'denzel is looking good',
#  'rt : s sarah paulson has arrived on the red carpet',
#  'kirmizi halida yaz disinda kış yaşanıyor sanki',
#  'leonardo dicaprio ❤😍😘❤',
#  '',
#  'so on  night i can only expect so many people to click through our link ://',
#  'salma hayek vestido lindo  mas cago no cabelo',
#  'rt : im on my highway to the red carpet',
#  'olha só salma toda linda jogando os cabelos',
#  'dress chosen by  for the   ; do u find her sexy n classy in it',
#  'helen mirren en badgley mischka  2013  tomen nota',
#  'ohaaa favorim salma hayek \nbu kadın giyinmesini biliyor',
#  '✅',
#  'george cloney saca a pasear cada año o cada premio en el año a sus mujeres',
#  'im watching the 70th annual golden globe awards (6853 others checked-in)',
#  'i dont like it but everyone else seems happy i think shes got my uncles hair cut',
#  'sofia vergara proof of a god',
#  'vera wangs gown that was worn by julia louis-dreyfus is magnificent',
#  'love kerry washington - just beautiful',
#  'rt : adele at the golden globes looking fucking stunning',
#  'i love that george clooney is dating miss hancock',
#  'danzels daughter cud pass for his wife good a thing he pointed that out lol',
#  'manicam on e at',
#  'nicole ritchie in a naeem khan gown gorgeous',
#  'la cuota colombiana en los   ♥',
#  'my boyfriend didnt take me to the  wtf but he still looks really sexy 😏',
#  'hugh jackman is fantastic',
#  'rt : john hams penis for best dressed',
#  'i just really think julianne moore always looks terrible at award shows',
#  '2 new hq pics of rob added to the  master post:',
#  'rt : ¿quien te viste mi amor yo lo compre todo en los buhoneros del centro',
#  'is it me or does everyone look really old',
#  'denzel and his daughter - sweetness',
#  'jessica chastain no le favorece el pecho nada',
#  'haters gonna hate  looks flawless',
#  'watching  and dying over benedict cumberbatch',
#  '',
#  'skyfall by adele esta pasadaaa',
#  'everyones wearing black lol',
#  'rt :  :3 leaa quiero ver a lea',
#  'rt : the hair the fashion the make up rt  whats your favorite part of the',
#  'jessica rabbit looks good a la sofia vergara',
#  'rt : jennifer lawrence being interviewed by e on the  red carpet',
#  'rt : now thats natural makeup done right marion cotillard',
#  'i love how everyone was saying the trend for tonight was gonna be color and everyone is wearing black',
#  'jennifer lopez and salma hayek i die',
#  's daughter has no chest awful dress choice',
#  'i dont like what anne hathaway is wearing',
#  'my favorites at the : 1 tina fey: lwren scott 2 taylor swift: dkny 3 jennifer lawrence: dior 4 amy poehler: stella mcart',
#  'they look absolutely stunning but must be freezing their asses off',
#  'salma hayek looks va-va-voom',
#  'orlando bloom :3',
#  'rt : marilyn monroe en los golden globes de 1960',
#  'all the latina girls wearing black 💁✌',
#  ': welcome to the big show  ://',
#  'rt :  manicure movie camera and film strip by redcarpetman',
#  'jessica chastain in gorgeous light blue gown by calvin klein collection :)',
#  'jennifer lopez is going body tonight bod-e werq',
#  'me recuerda salma un poco por el peinado a maria felix unnnn',
#  'a orlando bloom se le quedó la corbata en la casa',
#  'orlando bloom forgot his tie at home  - ch',
#  'one of my favorite actresses anne hathaway looks stunning she didnt disappoint shes my role model  😍',
#  'estas actrices que tienen toques latinos se pusieron de acuerdo con el vestido salma hayek igualita a sofia vergara',
#  'orlando bloom put on a goddamned tie',
#  'jessica nın calvin elbisesiruju ve saçrengi süpper',
#  'yes i will be live tweeting the',
#  'rt : awww denzel washington brings his daughter as his date',
#  'jessica chastain youre so cute',
#  'rt : its been 13 years since i stood on a red carpet with denzel washington  remember the titans i do',
#  'so many tragic looking pairs of tits on the  tonight',
#  'rt : gretchen weiners: stop trying to make the mani-cam happen',
#  'rt : aww denzel washington brought his daughter to the  thats soo cute',
#  'dont mind me just getting weak at the knees and slurring my speech over jessica chastain',
#  'anne hathaway - lovely white gown but with this short hair she needs something around her neck',
#  'rt : a work of (nail) art',
#  'me encanta la alfombra roja me hace recordar viejos amores  guapísimo',
#  'rt : is it too 2005 if we admit were crushing hard on george clooney',
#  'jessica chastain is great she is great in every role',
#  'rachel weisz licenzia lo stylist',
#  'orlando bloom where the hell has he been',
#  'salma hayek has serious bedhead and what is orlando bloom even doing there',
#  'black red and',
#  'sofia vargara looks soooooo good love her dress',
#  'el día en que megan fox no enseñe su tatuaje de la espalda pasará algo terriblemente fatídico',
#  'rt : denzel just arrived',
#  'is jessica chastain going bald at the part of her hair  thats sad   but she kicks ass killing bin laden and all',
#  'rt : helen mirren sigue mucho más atractiva que muchas que podrían ser sus nietas',
#  'leo is lookin fiiiiiiine',
#  'rt : rt if you wish you could be attending the  tonight',
#  'salma hayek beautiful dress and love the bow',
#  'kanina pako nghahanap ng live streaming ng  meron naman pla sa  &amp; amy p',
#  'whos dresses have you liked so far',
#  'sigam o goldenglobes no instagram tem foto rob já *_*',
#  'rt : denzel is looking good',
#  'rt : the red carpet: the only place where journos heap praise on their interview subjects you look absolutely stunning',
#  'rt : gorgeous rt : another pic of rob',
#  'that mint green  gown is totally on trend &amp; a perfect contract for jessica chastains',
#  'miranda kerr o____o',
#  'rt : vergara said she only brought 15 people with love it',
#  'rt : awww denzel washington brings his daughter as his date',
#  'rt : llega el futuro ganador del globo de oro: leonardo dicaprio',
#  'rt : no puede ser más simpática  ¡latina tenía que ser para mi es la que más se divierte en los',
#  'hugh jackman hugh jackman hugh jackman hugh jackman hugh jackman huge jackman',
#  'cagada maxima cuando le preguntan a dentzel washington por su mujer que esta a su lado y resulta que es su',
#  'did jennifer lopez slather herself with a pritstick and roll around in a pile of lace',
#  'rt : tina fey amy poehler on  drinking game: drink if someone cries has a fashion mishap or  if youve just had a tough week',
#  'being a fly on the wall of  `s  tweets funny like a lot of her commentary',
#  '',
#  'rt : my lord  is gorg',
#  'boring legolas is here',
#  'rt : pulling it all together beautifully - from the dress to the hair and makeup and jewelry - is so hard',
#  'orlando ^o^',
#  'rt : hearing selena gomez and vanessa hudgens are coming to the',
#  'ur  updates are my fave so far',
#  'rt : marilyn monroe en los golden globes de 1960',
#  'kreacher ha bailado con la chica de los juegos del hambre',
#  'rt : i have a pretty out of control crush on daniel craig',
#  'my sister is crying because denzel washington is just so cute i thought i was weird but i kind of get it',
#  'ver como la gente habla de la alfombra de los  con seriedad me da como cosica',
#  'you look stunning at  hope you win pretty',
#  'rt : awww denzel washington brings his daughter as his date',
#  'my favorite look of the evening so far the vintage movado watch is amazing every detail flawless',
#  'at',
#  'rt : on the carpet',
#  'rt : on the carpet',
#  'can try this:',
#  'so many dresses are literally drowning the wearers tonight ;/',
#  'salma is so damn sexy 46 years young',
#  'highlight so far',
#  'rt : hearing selena gomez and vanessa hudgens are coming to the',
#  'and if',
#  'me too ;)  i want to be anne hathaway when i grow up',
#  'love denzel',
#  'id prefer no discussion about dresses / designers thats time i will never get back',
#  'rt : denzel brought his daughter as his date shes an upcoming',
#  'jennifer lopez is stunning &amp; look 21 sexy as usual',
#  '“: photo: does bradley cooper go home a winner tonight  ” oh hai 😍',
#  'rt  the  ://',
#  'love kate hudsons dress she would have looked amazing had she pulled her hair up',
#  'wish i could figure out how to turn off closed captioning on my tiny tv so i could see all the gowns',
#  'rt : guys i just love famous people prom dont you',
#  'rt : edward',
#  'rt : on the carpet',
#  'paren el mundo ya llegó robert pattinson y leo dicaprio solo falta tom cruise y bam orgasmo',
#  'entirely wows on the red carpet in  at',
#  'rt : ¿y mas o menos cuándo empieza el show la alfombra roja como que ya aburre',
#  'rt : no puede ser más simpática  ¡latina tenía que ser para mi es la que más se divierte en los',
#  'my lady heart always squeals denzel whenever hes on my teevee',
#  'rt :  elegancia y carisma hecha mujer sofia vergara orgullo latino',
#  ...]

# %%
s = list(set(test))
print(len(s))
s
# Out:
# 122130
# ['',
#  'amy poehler y george clooney seria la mejor pareja del mundo',
#  'rt : best supporting actress in a motion picture - anne hathaway - les miserables -',
#  'i gots to drop you buddy  love your political stuff but i cant have you doing golden globes play by play  see you at the midterms',
#  '“: jlo is looking like sex at the golden globes 😍”truth',
#  'rt : congrats to the zero dark thirtysomething we get it its a struggle',
#  'kinda looks like bitches for not nominating ben affleck right now',
#  'golden globes party at the chi o house',
#  'that was bill rodham clinton -- tina fey',
#  'golden globes 2013: adele wins for skyfall: the british singer takes the hfpas top prize in the best ://',
#  'wow  wow im speechless with that speech &lt;3',
#  'im gon rewatch the pick 6 made by my dirty turlock quarterback and get mad again then see the flourish then watch golden globes',
#  'obrigado a gvt que me permite selecionar o áudio original ninguém merece a dublagem da tnt e do e',
#  'tina fey and amy poehler killed the opening monologue i wish they were handing out all of the awards',
#  'rt : not sure what jodie foster just said but somehow i was crying by the',
#  'ugh enough of jim parsons im over him',
#  'rt : ive never seen it but im surprised they called les miserables as a comedy musical i heard it was kinda depressing',
#  'after seeing mandy patinkin on tonights golden globes i will hereafter be referring to him as rabbi montoya',
#  'a canadian just won a golden globe',
#  'im bored is it considered rude to switch to  now',
#  'rt : jodie foster claire danes &amp; lea michele tina and amy as hosts les mis etc etc one of the best golden globes ever',
#  'rt : ojala tim burton esté viendo los  para que se entere que existen otros actores',
#  'con excepción de george clooney la pareja de muchos actores guapos más que sus novias/esposas parecen sus mamás',
#  'i tried to find a workable live link for the golden globes for someone but no luck the links are not direct or dont play at all',
#  'rt : \u3000golden globes theme to be released internationally coming soon\nゴールデングローブのテーマ曲がもうすぐ世界発売！',
#  'rt : quentin tarantino having my phone number is my personal fucking nightmare',
#  'tenemos que ver django ya',
#  'brave wins best animated feature film love it',
#  'is it just me or did bill murray just look like a dr suess character',
#  'mas votei em jack black',
#  'ay eva longoria siempre logra verse de 180 cuando en verdad mide como 150',
#  'what young man from brooklyn sporting highwaters that i probably knew in high school did lena dunham bring to the golden globes exactly',
#  'yup rt : amy and tina were perfection tonight so funny so amazing',
#  'si el vestido de kerry washington llegara al piso y tuviera un chongo lo amaría',
#  'tommy lee jones really enjoying himself',
#  'sofia vergara would bring 15 people to the golden globes typical hispanic 😂',
#  'dunham can barely walk but its the shoes bad dress choice bad tattoo choices good speech i still hate the show',
#  'rt : claire danes wins best actress for homeland more jazz',
#  ': jennifer lawrences nickname  - says will ferrell hahahaha',
#  'wanted damian lewis to win just to hear him speak in his regular accent',
#  'so happy anne hatthaway won she was amazing jessica alba looked amazing as always',
#  'eyyy look its batman',
#  'that was a tough category but i am really happy that  won for les misérables',
#  'v 7 vezes indicada e nunca ganhou coitada tinha q ganhar dessa',
#  'no he visto esa película pero ya era hora que anne ganará un  su trabajo es magnífico como ha crecido profesionalmente',
#  'well deserved win for -- both the american and israeli version',
#  'in a parallel universe adele and susan boyle are pissing themselves and playing with cats',
#  'props to will ferrell on his fred armisen impression',
#  'rt  did lea michelle and hugh jackman share a spray tan artist',
#  'anne hathaway has arrived',
#  'rt : dude ah-nold must be soooo stoked austria is representing',
#  'my entire tl right now: jodie is amazing jodie is psycho wtf is jodie talking about jodie looks amazing',
#  'some fun tweets about bill clinton at golden globes put together by',
#  'rt : god im such an idiot i meant the golden globes not the',
#  'rt : greatest tlj reaction shot ever',
#  'nice job at  rockin the burgundy stash',
#  'yay i love annie i need to see les miz',
#  'i like matt leblanc  i should totally watch episodes  anybody know if its on netflix or hulu',
#  'taylor is bringing austin to the golden globes  (۳˚w˚)۳ ♥',
#  'so arnold and sly were making fun of accents while presenting foreign film',
#  'taylor swift looked sad haha go adele',
#  'i really want to see silver linings playbook now',
#  'i am trying not to have feelings about hathaways speech but she is not making it easy eyeroll',
#  'tina fey and amy poehler are perfect when i grow up i want to be just like them that is all',
#  'anne hathaway if you need a funny fat best friend i am available',
#  'yayyyy so far glad that jennifer lawrence anne hathaway and brave won',
#  'zing that james cameron torture jab may be the line of the night',
#  'yo i dont care what anyone says: kate hudson is hot',
#  'darcy st fudge wins for my new alias',
#  'serious tweet: go ben affleck you really deserve it',
#  'yeah hath you will wrap it up',
#  'rt : kristen bell rocks her baby bump in a jenny packham gown',
#  'i cant see the handsomeness theyre talking about rt“: best of the  : bradley cooper ”',
#  'me encanta los golden globes porq esas mesas dan la impresión de q todos se echan cuentos se ponen al día y se caen a palos y tequeños',
#  'rt : helen mirren is the barak obama of red carpet frocks she just keeps getting cooler',
#  'clinton at the golden $ for hillary u showbiz ppl better hand it over',
#  'wasnt looking at the tv just now and said to myself who the hell sounds like bill clinton',
#  'rt : do you think when they go to commercial everyone laughs and shouts we are so rich money money money money',
#  'mejor actuación masculina en       2013',
#  'that might have been the craziest yet best  to date congrats to all the winners xo',
#  'bueno al menos a maggie smith le dieron un premio aunque laurence le robó a mejor actriz de comedia',
#  'katharine mcphee | golden globes 2013',
#  'los  son satánicos si observan bien notarán que tienen la forma de los testículos de satanás',
#  '“: wow ive never seen jodie foster open up so much about ”',
#  'what about glenn close talk about channeling cruella deville “: julia roberts needs hair help ”',
#  'aparte de su buen desempeño en los miserable anne hathaway gano su golden globe por no traer calzones',
#  'rt : aww muy bien jennifer :d',
#  'rt : the golden globes is actually boring as hell to me',
#  'christoph is brilliant at speeches',
#  'when a kid on the golden globes looks like your ex&lt;',
#  'legit thought that life of pi was about math lol i guess i was wrong',
#  'rt : tommy lee jones is such a douche why even show up if youre gonna stare at the ground all night and pout',
#  'kate hudson just does things to me',
#  'miranda kerr at the golden globes tonight tho😍',
#  'adorbs :)\nrt : this was how  took the award home:',
#  'rt : losing the golden globe is the second-worst thing to ever happen to lincoln in a theater',
#  'rt : fotogalería: la  en los  ://',
#  'i thought this was for the best tv show not the worst girls is awful',
#  'who else doesnt give a shit about this guys speech',
#  'eddie and rob having drinks together at ggs',
#  'tina fey and amy phoehler are killing it as hosts of the golden globes dont you think so',
#  'jennifer being interviewed at the',
#  'chris tucker at golden globes',
#  'could  look any more gorgeous',
#  'rt : jodie foster se ve hermosa encantador omenaje',
#  'anyone compile a list of golden globes live tweeters    etc',
#  'rt : amy poehler and tina fey have never looked so good',
#  'adele ganó por mejor canción original: skyfall taylor swift seguí participando',
#  'whoa damian lewis finally opened his mouth wide enough to speak',
#  'rt : you can keep your golden globes ill be giving free golden showers if anyones interested',
#  'halle must have stood twice in line for lasting youth skin',
#  'não tô vendo o golden globes por causa do meu irmão que legal',
#  'this guy is hammered',
#  'damn i missed him rt  ewan youre not visiting a friends',
#  'a mina do glee tá laranja',
#  'yeah jlo- mad you let him go now get it ben',
#  'richard gere is the most gracious man there',
#  'fat jonah hill &gt; skinny jonah hill',
#  'dios miooo  esta hermosaaaaa',
#  'hey its the golden globes this is to me what vs is to horny young boys please understand will make up for it tmrw promise',
#  'so are you getting ideas for your future hosting job tonight',
#  'rt : robert downey jr is a prime piece of man meat',
#  'i love adele shes hilarious and seems so genuine',
#  'she looks horrible everywhere rt  heard taylor swift is looking horrible at the golden globes lmao',
#  'are people actually giving jennifer lawrence shit for the meryl comment ah come on have a sense of humour',
#  'rt : i need a gif of glenn close right now',
#  'clooney and poehler - they could be the next nick and nora charles',
#  'uncomfortable moment for casper (jlos boytoy) having ben affleck bradley cooper &amp; diddy under the same roof',
#  'rt : tina fey and katie couric made a huge impact on the election this is why we cant have nice things',
#  'this time tell us who helped you make it through elementary school lena',
#  'good night &amp; thank you for',
#  'watching the golden globes hoping i see aaron paul',
#  'rt : love that anne hathaway gave a shout out to princess diaries  never forget where you came from',
#  'amazing “: a gif of jessica chastain reacting to james cameron joke by amy poehler: ”',
#  'rt : love her haircut ** rt : anne hathaway lució hermosa con un vestido blanco de chanel',
#  'these men  *fans self* still lookin good at their 😍😍😍',
#  'daniel day lewis is a very very handsome man',
#  'remember when everybody freaked out &amp; thought ricky gervais disappeared this is your reminder it happens every year',
#  'jennifer lopez lleva el encaje pegado a la piel qué lograo jajajaja',
#  '50 años y se ve impresionante',
#  'se depravaron con bill clinton presentando a lincoln en los golden globes',
#  'congratulations ben affleck for your best director award by  argo',
#  'just sayin silver linings playbook was actually really really good jennifer lawrence deserves all the awards',
#  's creepy friend now',
#  '“: ran into two of the most beautiful girls of the night  and   ”',
#  ': se terminaron los  mañana a buscar las películas en su puesto pirata más cercana cruel pero muy cierto',
#  'meanwhile claire danes has never been tan  ever',
#  'rt : amour ganó el premio a mejor película extranjera',
#  'is sascha baron cohen ever *not* in character',
#  'amy poehler y tina fey están haciendo un monólogo sobre los premios y los nominados',
#  'menos de media hora para los',
#  'bill clinton that is just weird',
#  'los globos de oro esa loca gala en la que creen conveniente rodear a mel gibson de alcohol y judíos',
#  'on the to do list: watch',
#  'btw so proud of and happy for',
#  'the golden globes are fun and all but ill really care when we get to the academy awards',
#  'that was the most awkward international music star i have ever',
#  'dije toda la semana que iba a ver los golden globes y se me olvidó :(',
#  'quentin tarantino is here the star of all my sexual nightmares lolol i cant even',
#  'rt : les miserables wins best',
#  'hugh jackman is an absolute man he can literally do everything',
#  'after a lovely quiet dinner at the odeon with mrs hazard i shall now join the twitter community in providing golden globes snark',
#  'melhor filme de animaçã$ 185 milhõ$ 500 milhões',
#  'ha  rt : rt : so many taylor swift songs about adele',
#  'christoph waltz just owns this award haha',
#  'this will prob get me a few unfollows but whatever: i think anne hathaway is fantastic',
#  'i want to marry someone who loves me enough to mention me a lot in their golden globes speech',
#  '“: ¡les miserables gana como mejor película de comedia y musical ¡nos urge que se estrene en méxico ” por favorr',
#  'jodie your speech has 150 plot lines but im also a wee bit weepy',
#  'ewan mcgregor is my ideal man now and forever',
#  'life of pi wins best score poor cloud atlas',
#  'lmao that woman really loves saying vergara',
#  'omg its bubba hey there mr president perfect person to introduce',
#  'well this',
#  'rt : mejor banda sonora original: life of pi',
#  'tina faye and amy polar hosting the golden globes 😂👍',
#  'é a primeira vez q vejo uma chinesa com um olho maior q o outro rt : cosplay de mesa:',
#  'im proud to say that im not watching the golden globes but that im writing like there is no tomorrow  yay for productivity',
#  'siempre es bueno verlos a sly y a arnold juntos',
#  '“: clinton still the biggest star in the ” got the biggest standing o',
#  'golden globes 2013: new mother megan fox dazzles in ://',
#  'halle berry looked stunning on the   have u seen the trailer for her new movie the call watch it here',
#  'really whats not to love',
#  'wtf why brave i hope this doesnt jeopardize tim burtons oscar chances frankenweenie is the animated film of the year',
#  'and  are killing it on  omg so funny',
#  'is on stage right now and she is rocking that dress',
#  'i remember seeing these people on the set  btw movie filmed in',
#  'default run tonight for strengths and weakness time for',
#  'rt : daniel day lewiss acceptance speech was the daniel day lewis of acceptance speeches',
#  'anne hathaways speech would have been better if she had been cast in the role of a woman accepting an award',
#  'siempre me trauma cuando veo a adele y recordar que tiene 24 años  se ve mucho más grande pero bueno wohooo por skyfall',
#  'hey  they just played robyn on the golden globes',
#  'rt : i want to hang out with adele and tina and amy',
#  's dress and love that homeland is killin it',
#  'loving miranda kerrs \xa0awards look',
#  'nooooooooo f that movie',
#  'true s not giving up yet on jenny from the block',
#  ': skyfall by adele wins best song unsurprisingly seriously adele should sing the theme song for every movie',
#  'rt : its cute how the golden globes pretend everyone doesnt refer to them as no not the oscars the other one',
#  'my dream  ser aplaudida de pé por todos esses que estão no \npor melhor atriz de comédia da série glee',
#  'that wrap it up music totally made daniel day louis speech better',
#  'rt : i love anne hathaway and i haven’t even seen les mis what a class act',
#  'love anne hathaway',
#  'sofia vergara podría hablar bien inglés si quisiera',
#  'hot damn tina fey',
#  'emily blunt',
#  'kind of wanted affleck to say hey j-lo eat shit bitch',
#  'tina fey e amy poehler no palco começou',
#  'i am hoping kanye is there with a bottle of crown royal',
#  'i loved',
#  'rt : watching golden globes whoa its like a cavalcade of stars',
#  'waiting to see rt : ah so leonardo dicaprio is wearing tom ford well',
#  'les miserables yessssss',
#  'les miserables ganó otro robo',
#  'rt : love that lena dunham cant walk in her shoes thats real people',
#  'podemos esperar músicas de taylor swift reclamando por ter perdido o golden globes',
#  'quentin tarantino reminds us that someone who cant speak can still write and direct',
#  'i predict at least seven jabs at gun owners / the 2nd amendment during the   call me',
#  'rt : ¡¡¡ganó girls de hbo debo confesar que la serie me atrapó desde que me topé con ella en hbo excelente guión y timming',
#  'wow is that an upset or what',
#  'i wanna see  sexy self on stage',
#  'rt : philly in the house',
#  'taylor swifts  is not',
#  'game change: the cure for the common tv movie',
#  'i keep thinking carrie coming off a jazz club right into the award show with her makeup',
#  'michael bluth en mayo nos volvemos a ver',
#  'nice dress and look taylor',
#  'its the  buddy',
#  'jack black is so stoned at the  its not even funny',
#  'estos golden globes awards se estan poniendo buenos',
#  'me encanta ver a michael j fox en',
#  'meryl streep called in sick from the golden globes',
#  'venceu pi apostei em lincoln 5 de 7',
#  'good job argo team production your movie won the  uhyeah',
#  'looks stunning in  commerical before',
#  'darn max greenfield i was rooting for you',
#  'i just got goosebumps from the segment they did on les mis',
#  'rt : mucha ternura ver a ben affleck tan emocionado y nervioso recibiendo su globo de oro al mejor director',
#  'yoshiki yoshiki yoshiki :3',
#  'who wears a baseball hat to the golden globes',
#  'warm up with the',
#  'if you’re watching the golden globes please tweet about it',
#  'rt  tina + amy got the party started right their 7 best zingers from the  opener:',
#  'rt : barbara and selena are both at the golden globes lmfao i hope a catfight happens and barbara pulls out selenas weave',
#  'is it just me or is comedy or musical a really arbitrary combination',
#  'rt : argo wins',
#  'rt : is blerg in the dictionary',
#  'ole este sí',
#  'rt : adele: weve been pissing ourselves laughing all night',
#  'começoooou',
#  'y liv taylor lo habia muerto',
#  'yes christoph waltz totally owned that role in django',
#  'she isnt very good at acting surprised is she',
#  'taylor swift was shooting daggers from her eyes at adele eat it bitch',
#  'am i watching an old broadcast of the  from 96',
#  'and  killing it with the opening monologue at the',
#  'man im feeling jessica alba too the latinas decided to show out tonight',
#  'rt :  i see what you did there i am too and im watching the golden globes d:',
#  'yes  go ahead and try to play off daniel day-lewis youll just making his speech more dramatic and inspirational',
#  '“: gostei da relação bill clinton apresentando lincoln oscars se mordendo de inveja da ideia ”',
#  'and amy hits it out of the park  when it comes to torture i  trust the lady who spent 3 years married to james cameron',
#  'so fun to watch fey joking about playing s palin at the  in front of julianne moore btw i did enjoy game changer lots',
#  'kristen wigg and will ferrell had me dying laughing',
#  'ahora todos a',
#  'rt : veo los golden globes y solo puedo pensar que tengo que ver demasiadas películas',
#  'yawn one actor wasted on a ripoff show and one bore who is over rated',
#  'and d golden globes begin right away',
#  'i want to be friends with  she is delightful congrats lady',
#  'rt : brave and girls just won back to back i officially hate the',
#  'shut up jodie foster and get off the stage please',
#  'the  are on',
#  'la sorpresa  mejor director ben affleck por   excelente peli  bien ah',
#  'daniel day lewis does not give a damn about wrap-up music',
#  'wheres the music',
#  'ew they just flashed skylar white on the screen',
#  'rt : amour (austria) wins best foreign film | via',
#  'congratulations to the cast of homeland',
#  'wooowww ben affleck is worth it  rt : best motion picture - drama -  -',
#  'omg please come back to snl amy poehler this is definitely her niche    poehler',
#  'bon en même temps cest du caca industriel les',
#  'being brave is about not shouting into the',
#  'rt : ¿qué tal el look de robert pattinson en la alfombra roja de los',
#  'hi e is kyle &amp; maurice at  tonight',
#  'like anyone in america thought jodie foster was',
#  'lena dunhams award and speech will launch a million blogs and think pieces',
#  'yay for  at the',
#  'el jean valjean de les miserables gana el premio a mejor actor para película de comedia o musical',
#  'oh no too bad bradley cooper didnt win :(',
#  'all in all a very satisfying evening congrats to   &amp;',
#  'golden globes 👌',
#  'best animated feature film goes to brave    congrats',
#  'hayden panettiere looks stunning',
#  'jennifer garner &amp; ben affleck - golden globes 2013 red carpet: jennifer garner and ben affleck put on their ://',
#  'ovación a la subida al escenario de los  de bill clinton',
#  'rt : best editing goes to the golden globes staff for finding 45sec of django unchained that didnt include the n-word',
#  'i want argo to win lots of things',
#  'rt : i dont care what anyone says i love ben affleck and jennifer garner so glad he won',
#  'qué guapo robert pattinson',
#  'rt : jajaja rt : gaga cantará bill romance ahhhhhhhhh rt : ¿qué carajo hace bill clinton ahi',
#  'impresionante los vestidos en lo  quiero uno como el de catherin',
#  ': dame  wins at  - best supporting actress in a tv movie series or miniseries for  yeas',
#  'rt : tonight i feel like the prom queen ~jodie foster',
#  'watching the  and doing  ahhhh',
#  'jodie fosters speech made me cry hahah',
#  'bill worked that room like they were donors  oh',
#  'rt : last-minute bengay rub down in stallone and schwarzeneggers dressing room',
#  'rt :  and we dont care about you   because now we can safely say that they are biased and cheaters',
#  'les escupo en la cara a los que están haciendo la traducción de los golden globes',
#  'psycho babble coming out of some the golden globes actors mouths is ridiculous',
#  'golden globes: no need to take a poke at sarah palin when game change just won a statuett',
#  'rt : inspired by  were having moët with pulled pork tonight',
#  'ohh my gosh he totally did -- definitely over it',
#  'lawrence seems like kind of witchy but with a b',
#  'this  show has been wayyyyyy to much fun to watch the  speeches were priceless',
#  'jim parsons deserved that :-(',
#  'amy &amp; tina are making everyone laugh they are the best hosts for the  :)',
#  'adele continues to take over all of the music',
#  'i love tina feys dress she and amy are cracking me up',
#  'watching the  when am i going to be there',
#  'yes ben affleck wins',
#  '“: best television series actor - drama - damian lewis () - homeland () - ” my boy',
#  'amor de austria gana globo de oro por mejor película extranjera',
#  'i admit im a sucker for all award shows  but what a bunch of pretentious know-it-alls on the golden globes',
#  'from a comedy perspective i probably should be watching the golden globes but from a fuck these annoying celebrities perspective i cant',
#  'rt : i love jodie foster ❤',
#  'four more years four more years',
#  'rt : adele ya tiene el óscar a mejor canción asegurado\ngana por skyfall en los',
#  'eddie redmayne is looking fine at the golden globes tonight  ☺',
#  'rt : what do you guys think of jlos dress',
#  'jlo=smokeshow',
#  'zoey deschanel o_o',
#  'jason statham and jennifer lopez on the stage together im not sure my tv can stand that much hotness at once😳🔥',
#  'hello rocky',
#  'i wish i had cable',
#  'comes as no great surprise as shes in michael kors but i think emily blunts dress is awful so tacky for such a classy lady',
#  'i would be a terrible celebrity ive decided after watching the golden globes',
#  'everyones watching the  and im sitting here doing',
#  'oh putain sacha baron cohen qui mentionne depardieu dans son speech',
#  'life of magnum pi',
#  'yes rt : omg gosh michael j foxs son looks just like him',
#  'rt : jenny from the blocks skin is always flawless &amp; radiant  while',
#  'rt : best opening for an award show ive ever seen',
#  'jessica alba looks amazing tonight',
#  'jennifer lawrence mejor actriz',
#  's tweets are so hilarious right now',
#  'ben affleck deve ta feliz demais agora e isso me deixa enlouquecido argo fuck yourself',
#  'rt : another shot of sarah paulson on the red carpet',
#  'leonardo dicaprio no pega una seguro ya está en el estacionamiento buscando el carro',
#  'rt : thanks for this    party-watch going back to my meth franchise now',
#  'rt : chegou o dicaprio escondam os prêmios~~',
#  'video: robert pattinson inside the golden globes',
#  'seriusly not a bazinga for sure jim parsons should have won',
#  'rt : kerry washington is so pretty',
#  'dios will ferrell o como se escriba ese tipo es de lo peor no tiene gracia',
#  'lena',
#  'robert downy jr 😍😍😍😍',
#  '“: and never forget: taylor swifts side eye   ” if e tweeted it its legit',
#  'waking up to a very good news that ben affleck won best director and argo won best motion picture (drama) at the golden globes :)',
#  'i said it last year and it still rings truematt le blanc looks perpetually suicidal',
#  'and the  goes to ed harris',
#  'and the golden globe goes - said no one ever',
#  'guys can someone give me a ride to wherever the argo after party is',
#  'rt :  best foreign films : amour',
#  'ben affleck amerikanın mahsun kırmızıgülü galiba',
#  'rt :  jessica chastain zero dark thirty  mejor actriz – drama',
#  'amy adams always looks sooooo scared its okay',
#  'verga dos golden globes para homeland voy a tener que ponerme a ver la serie',
#  'first two awards at  bang on',
#  'bill clinton they even surprised me with that one',
#  'i see you bill rodham clinton i see you',
#  'best actress in a motion picture musical/comedy goes to jennifer lawrence',
#  'youre not the only one frustrated“: trying to look for benedict cumberbatch in the ”',
#  'que todo mundo já viu e adorou (eu sigo em dívida)',
#  'i love lena',
#  'apparently the style for 2013 is to forget the fabric from your neck to your belly button',
#  'was  wearing a dress or stickers',
#  'rt : rt : let me know when the  celebs go on stage and pledge to stop portraying gun violence in their shows',
#  'amén rt : paul ruud siempre será el marido de phoebe buffay y punto',
#  'am i the only one missin  during this   event',
#  'rt : bill clinton is on the  this just in: the golden globes have jumped the presidential shark',
#  'my boy  is looking realllll goooood on stage',
#  'rt : ready for this great idea  and i host the golden globes oh my god thatd be great',
#  'por que no esta maggie smith quiero que recoja su premio tranformandose en gato por favor',
#  'look monchele in the golden globes last year :)',
#  'migrem …',
#  'rt : who was not wearing their eagles jersey bradley cooper is robbed we think() in the best actor (comedy/musical category)',
#  'aww i spotted adele on the golden globes',
#  'jennifer lópez calata como siempre',
#  'wach the  from colombia',
#  'paul rudd tries to save  error but sinks',
#  'you guys live tweeting sports and the golden globes id totally log off twitter if i had something/someone better to do',
#  'rt : borat lol',
#  'im assuming id have to be a part of the hollywood elite to understand any of that speech rdj just gave about jodie foster',
#  'seeing  at the golden globes even pisses me off   but actually you dump guys too soon to suck dick',
#  'head on over to  where ill be tweeting all night covering the',
#  'amanda seyfried and robert pattinson would be such a cute couple',
#  'ahhahaha amanda and rpattz its like shes deathly terrified of him',
#  'i only get one comment from you on the  and its wow jody',
#  'snaps to anne hathaways speech because of her shoutout to her people back in genovia',
#  'the problem with watching a love awards show is that you cant fast forward through the acceptance speeches',
#  'somewhere in boston matt damon is mourning clooney replacing him as ben afflecks bff',
#  'skyfall wins best song',
#  'rt : bill murray = the lorax love that',
#  'tengo demasiado sueño como para ver los golden globes pero al menos quiero ver una foto de selena solo eso',
#  'golden globes ✨',
#  'robert downey jr *--* dios míooo me caso demasiado',
#  'tom haverford',
#  'id still vote for you jack black',
#  'skyfall congrats adele',
#  'rt : rt : jodie foster is giving not a single red velvet fucks tonight',
#  'jodie foster is my  favorite actress hope we get to see more of her amazing talent',
#  'tina fey and amy pohler are like a dream team together amazing',
#  '“: sylvester and arnold look so old ” cause they are',
#  'sofia rt : who has the better accent:  or',
#  'insert tweet about golden globes here',
#  'added screenshot of rob shaking quentins hand',
#  'good god this is the greatest award show of all time',
#  'sexy',
#  'rt : interesting fact; 90% of the people congratulating don cheadle on twitter have never seen his show',
#  'i cannot wait for new arrested development',
#  'wins best animated film at  this category doesnt get enough respect',
#  'you go  yessss',
#  'deffffinitely',
#  'rt : amy adams at golden globes in  what an amazing dress',
#  'lawd they done let bill clinton in the room',
#  'best of luck you all look amazing',
#  'y el mejor director de peliculas de drama tito vilanova',
#  'fuck you homeland guy for spoiling',
#  'complete list of the winners at the 70th annual golden globe awards',
#  'and were already down one meatball sub for harvey',
#  'when the salmon comes re in  omg kristen wiig and will ferrell are perfection',
#  'oyey no fue   woooo no lo creo',
#  'ben affleck slow down i cant understand you',
#  'i cant feel my ears -my boyfriend',
#  'that is a wow moment\n\nrt : ben affleck wins best director for argo wow',
#  'slumber party with my two besties  and',
#  'i just got a text from brother asking me to tweet something about anne hathaway being stupid best family ever',
#  'nice jessica chastain for best actress',
#  'film wajib tonton ini : daniel day-lewis wins best actor drama for lincoln',
#  'los  están haciendo aflorar mi parte mas frívola y vanal  que lindoo',
#  'photo: wet-violet: are you kidding me good “golden globes” night',
#  'would be perfect if bill paxton ambushed him',
#  'rt : congrats to  well deserved',
#  'rt : adele rules the world for real',
#  'ed harris se lleva el  a mejor secundario por game change su tercer premio homeland ya no hará pleno',
#  'rt : jodie foster pure class',
#  'george clooney is the epitome of handsome',
#  'yay anne hathaway wins best supporting actress for les mis well deserved',
#  'cheers to a great night rt : our  is off to the parties we hope you enjoyed the show',
#  '(via popsugar) sofia vergara goes sultry at the golden globes:',
#  'the odds was so ever in jennifer lawrence favor',
#  'rt : getting ready for the',
#  'jonah hill looks so out of place haha love him',
#  'oy will some tell helena bonham-carter about the way she looks please',
#  'kate hudson looks ravishing',
#  'rt : thank you for the best string of yesterdays i have ever had - anne hathaway {best quote of the night}',
#  'hey  argo fuck yourself for your exclusion of ben affleck as best director',
#  'ive said it before and ill say it again patinkin is a liar',
#  'look you guys im trying to watch golden globes and you are making me thinkaaarrgghhh',
#  'more tina and amy pls',
#  'no te pongas tacos si no podes caminarrrrrrrrrr lena dunham',
#  'heckling the golden globes with stacy and the girls  doesnt get any better',
#  'the early verdict is in and amy poehler and tina fey have already won 2013',
#  'nice fake accent bale',
#  'theyre not reality says christoph waltz of award shows on the red carpet',
#  'rt : congrats to  for winning the temple grandin enough already award at the  for',
#  'rt : im pretty happy taylor swift didnt win an',
#  'and the  are on at the same time tonight:',
#  'welcome one of the most over rated presidents of our time',
#  'golden globes over friends it is',
#  'decidme que el camarero de la fiesta es joaquin phoenix',
#  'primera vez que veo derrotada a taylor',
#  'im missing the golden globes to see a movie i think thats the right choice for a movie nerd like me',
#  'so did anyone see the master or was it just me also no love for sherlock',
#  'i wish i was the child of celeb parents so i could just stand on stage pass out awards and mingle with celebrities',
#  'i can already tell the golden globes are gonna be so good tonight',
#  'rt : i already did my coming out about a thousand years ago-jodie foster accepting cecile b demille award',
#  'of',
#  'the greatest thing i saw at the golden globes was bill murray chatting with aziz that would be my dream conversation',
#  'bellooos los 2 rt : kate hudson creo que te',
#  'adele siempre se viste y peina igual no',
#  'taylor en los golden globes awards',
#  'thank you very much were going home with jodi foster amy poehler and tina fey ending the  :d',
#  'who decides these golden globes who is this foreign press they keep mentioning',
#  'tweets com eco',
#  'lots of hottie cleavage out tonight for   im holding out for daniel day-lewis to show us his goods  &lt;3 him',
#  'i need to see the bottom of sienna  millers dress',
#  'seriously julia roberts enough of her already',
#  'nene looks awfully wide in that dress shes wearing',
#  'a vagina joke followed by animated films i wanted to describe that in words',
#  'a ponernos comodos para ver los   :)',
#  'tina fey and amy poehler killed it love them to death',
#  'mejor película (comedia o musical): los miserables',
#  'im next',
#  'i had to unfollow  b/c they are tweeting the winners before i see them on my tv',
#  'rt : number one complaint about the : not enough tina/amy action',
#  'please speak hebrew to me saul',
#  'the fuck is swiftly there for',
#  'j to the  jennifer lopez laces up for the',
#  'rt : the gals on twitter hating on hugh jackmans wife for not being young &amp; pretty: youre part of the problem',
#  'rt : mad men (which wasnt even nominated) had probably the best season of television ever in 2012 just saying',
#  'pues me está encantando el inicio de la gala de los  muy grandes fey y poehler',
#  'two of my favorite cast of snl will ferrel and kristin wiig',
#  'can someone remind anne that she was only in like 20 minutes of the movie',
#  'did you know theres a little man underneath the stage that adjusts the mic for each speaker its rob schneider',
#  'the golden globes were like a consolation prize for ben affleck',
#  'mini serie para tv game change',
#  'if tommy lee jones face hasnt been memed yet i dont even want to know you internet',
#  'and now a little of what got me the part',
#  'im talking about the golden globes lol during acceptance speeches they start playing the music',
#  'rt: maggie smith la eterna profesora minerva se lleva su',
#  'best mini-series/tv movie: seen none of them sadly',
#  'tina fey and amy poehler are the best hosts that theyve had un a while',
#  'must have  hair',
#  'ejella marico ejelaaa es marta columina en los golden globes oo',
#  'she said she {taylor} needed some me time pretty much she told her to stay single',
#  'rt : hair hang over side parts dominated the red carpet tonight @ the',
#  'live ba yung golden globes sa sw :))',
#  ': scratch that maybe will ferrell and kristen wiig for  2014 hosts yeap definitely',
#  'como alguien no puede amar a adele tan linda ella muy buen discurso bien emotivo',
#  'yes “ best actress in a motion picture musical or comedy: jennifer lawrence  ”',
#  'anyone else watching the golden globes',
#  'rt : the awkward moment when ben affleck professes his love for his wife and jlo is in the',
#  'so thats where my curtains went',
#  'ben affleck mejor director argo',
#  'benedict should have won he deserves it more than anyone',
#  'the  is stifling my tweets lol',
#  'lots of red and black at the  miranda kerr looking amazing in wine/burgundy',
#  'rt :  and 2013s golden globe awards for best female goes to: dona nenê a grande família',
#  'what was censored',
#  'rt : señoras y señores bill clinton en el escenario de los  ovación de pie',
#  'me estoy perdiendo los golden globes',
#  'rt : im watching the golden globes and i just really want to be famous',
#  'louise roe en los',
#  'jodi foster wow crazy coming out speech :) very inspiring',
#  'rt “: el show de la cirugía ” - jaja',
#  'best pic for comedy musical goes to',
#  'just love adele  fanks',
#  'rt : heres the part of jodie fosters speech that has people wondering if she came out as a lesbian:',
#  'who even needs to watch the  when you have a twitter',
#  'congrats hugh jackman  #',
#  'bravo who needs the golden globes when we have reality sunday with bravo love you bravo 💏',
#  'if the golden globes arent gonna give me more liz lemon i guess im gonna have to waste my time doing something else',
#  'rt : leooooooooooooooooo',
#  'is it just me or do all the actresses on the  look unhealthy skinny \n\n(jlo eva longoria and kerry washington look amazing)',
#  'what happens on vegas stays on vegas',
#  'omg lea michelle looks crispy as hell',
#  'day dreaming about one day seeing a starlet wearing lilly lorraine on the',
#  '-soldado cual es la mejor forma de desarmar una bomba -en la que no muero general',
#  'jessica diva linda perfeita',
#  'im actually obsessed with the entire cast of les miserables tonight',
#  'rt : even adele wins at the golden globes i love her yes',
#  'who wrote this womans jokes because she is not doing them justice at all lol',
#  'bale when u gonna shave bro',
#  'still dont get lumping comedy and musicals together but les miserables  wins so guess it doesnt really matter',
#  'soo how do i get an invite to the grey goose bar',
#  'rt : the way ben affleck spoke about his wife on the golden globes my heart just melted out of my chest cavity',
#  '2013 golden globes -- red carpet photos: the 70th annual golden globes are in full swing and as usual theres ://',
#  'will ferrel and kristin wiig and will ferrels mustache',
#  'i feel like my best friend just won a golden globe -  (while she is crying)    ”',
#  'rt: : whoa quentin tarantino just said the n word backstage i think everyone in here gasped',
#  'rt : jodie foster habló de kristen en el backstage de los  «3',
#  'rt : golden grahams &gt; golden globes',
#  'rt : will ferrel and kristen wiig need to make a movie together that is all',
#  'also miranda kerr looks stunning',
#  'rt : pero qué mal encubre su muerte batman si hasta sale presentando un premio y todo',
#  ': algun dia algun hermoso y soñado dia que no saldrá de mi mente yo estaré en los golden globes lo sé',
#  'our prince of new jersey',
#  'big willy',
#  '¿tienen un link para el stream de los golden globes',
#  'lena needs to learn to walk in her shoes or just take them',
#  'who is this zombie',
#  'will ferrell and kristen wiig have stolen the show done and done',
#  'anna hathaway meilleure actrice de soutien :)',
#  'is that the fella from true lies that ive never seen since yknow the fella with the camera bazooka whatever thingamajig',
#  'everyone knows the  are a scam',
#  'golden globes forever giving the guy who wont win an oscar the top award',
#  'how must i redo my room watch the golden globes and eat pizza all at the same time',
#  'id be happy if catherine zeta jones never sang again',
#  'the things i would do to become a seat filler at the',
#  'jodieeee 😿',
#  'someone tell kristen bells dress the cat on a hot tin roof revival is going on &amp; the no-neck monsters have already been cast',
#  'meilleur film dramatique récompense bien méritée',
#  'rt : that was hilary clintons husband haha i love amy and tina',
#  'rt : i would love to be at the golden globes right now',
#  'holy shit heisenberg is at the',
#  'rt : blergh thanks for that word tina - anne hathaway accepting for les miserables',
#  'descontão hoje 20000 followers por : :',
#  'rt : most racist wolf-whistle ever',
#  'omgf bill clinton is at the golden globes day has been made my hero',
#  'lea michele that is not a human skintone',
#  'tammy gretchen como figura cenografica do ano',
#  'tommy lee jones may be a good actor but he cant not act like an asshole',
#  'julianne moore is a class act',
#  'paul rudd you showstopper you',
#  'tina fey &gt;&gt;&gt;&gt;',
#  'rt : one day i wanna go to the golden globes😍🏆',
#  'serving champagne at our  viewing party at home',
#  'rt : less awards more tina and amy',
#  'para mi las mas guapas de los  son jennifer lawrence megan fox y michelle dockery',
#  'even mel gibson is fully confused what the hell is happening  ok she got me with the  mom part',
#  'i love jody foster movies definitely deserving of this award',
#  'lea michele is not a good reason to change shampoo',
#  'rt : ben triunfaste',
#  'love you commentary i still say soap stars should be nominated for  as well you guys work a whole lot more',
#  'brave over wreck-it ralph wow  i wonder if the hfpa even watched brave',
#  'nominacion: mejor actor de reparto en una pelicula: c waltz',
#  '“: which of tonights red carpet couples was the cutest  ” ben affleck n jennifer gardner always',
#  'rt : omg this is so perfect',
#  'rt : i wouldnt even know the golden globes were on if not for twitter thanks for ruining my night you celebutard sycophants',
#  'mejor actor de reparto en una serie de televisión - ed harris - por cambio de juego',
#  'rt : mel gibson aún no se ha metido en peos',
#  'rt :  bill clinton at the golden globes did someone tell him it was the avn awards',
#  'sofia vergara le vuela la raja a maggie smith',
#  'happy about argo (saw it twice) but sad not a single ar go f*ck yourself was uttered in an acceptance speech',
#  'adele just needs an academy award and shes alllll set :)',
#  'that was a great golden globes glad i watched',
#  'i think jodie foster just had a mental breakdown on national',
#  'having just seen  today jessica chastain is incredible in it very well-deserved award',
#  'emily let me give you my shoulder',
#  'glad thats over byeeeee',
#  'rt : bringing bill clinton out to introduce lincoln at the golden globes was easily the coolest thing ive seen on tv in a really long time',
#  'a mel gibson le falta nada para babearae',
#  'and now the nominees for best nominee to not win an award',
#  'rt : vanessa hudgens y selena gomez se ven bien perras es los',
#  'rt : anne hathaway is still my favourite of the night and after that speech shes become pretty hard to beat',
#  'golden globes 😄😘',
#  'rt : tommy lee joness reaction sums up how we feel about not having baseball during the offseason',
#  'jason bateman -- another fox',
#  'paul rudd for the win',
#  'esas bolsas necesitan una operación clinton',
#  '“: o and maggie maggie smith won  ” profesora ❤❤❤❤',
#  'homeland (2011– )',
#  'totally agree for a second i totally forgot about not liking her dress during that awesome acceptance speech',
#  'rt : mejor canción original: skyfall/adele',
#  'bellisima =)',
#  'okay daniel day-lewis my body is ready',
#  'make the jokes but jodie foster is still cooler and a better actress than 90% of hollywoods actresses',
#  'argo merecía ganar esa categoría',
#  'stand by people quentin tarantino just dropped the n-word backstage',
#  'e o comentarista diz que moonrise é bonitinho',
#  'rt : i sense an awkward disturbance in the force no wait that was just jodie foster',
#  'i really wanted  to win for  but congrats to',
#  'lindsay lohan kinda impressive shes still alive mt : guess whos getting the lifetime-achievement award',
#  'you did not just  the  :d lol',
#  'rt : quando avevo 11-12 anni ben affleck era sulle copertine adesive del cioè per sua fortuna non lo sa',
#  'eu quero é novidade se amor não ganhasse eu sufocava no travesseiro não',
#  'obi-wan en los  o:',
#  'i would love to tweet my thoughts about the happenings at the  but unfortunately nobody cares :(',
#  'rt : nailed it -- jodie foster to herself right now',
#  'yay  and the premier of  season 2 tonight--see you again in just a few hours',
#  'rt : adele = adorable and sincere &amp; so sweet',
#  'jodie foster was here what the artist in each if us is truly saying',
#  'lena dunham can do no wrong',
#  'love kate hudsons dress she would have looked amazing had she pulled her hair up',
#  'like don but jim is my fav bummed he didnt win',
#  'great show golden globes by next year i wanna be there lol',
#  'lol “: that is such a ho dress ”',
#  'rt : damn jodie had to make me cry',
#  'hilarious rt : were going home with jodie foster — amy poehler delivering the last line of the',
#  'nice technical difficulties',
#  'i may have to watch that show',
#  'anne hathaway sua linda &lt;3',
#  'jodie foster luce increíble a sus 50 años intachable carrera como actriz hoy recibe tributo en los  via',
#  'rt :  i said the same thing about chris tucker',
#  'hey taylor it is ok to lose and be happy for the winner',
#  'when we turned on the golden globes all productivity in little 206 halted',
#  'eu nem entendo inglês direito mas assistir sem a voz do rubens ewald filho é libertador',
#  'here comes anne hathaway - hit the mute',
#  'rt :  en los  por',
#  'se ve hermosa en los globos de oro',
#  'teleprompter fail',
#  'giulianas dress on the golden',
#  '¡ya empezaron los  por tnt',
#  'this is one of the (many) reasons i miss u rt : i challenge you to find a category that wont make me cry tonight',
#  'kevin costner is kind of a downer',
#  'wait why is taylor swift at the golden globes',
#  'ganó nuestra chica',
#  'rt : if tommy lee jones face hasnt been memed yet i dont even want to know you internet',
#  'best foreign film: who cares cant speak englisht much time no one cares',
#  'kerry washington has been killing it lately loved her django tour dresses and loving her miu miu at the',
#  'i think i just saw iron man tonguing mel gibson',
#  'michael haneke sounds nothing like  disappointingly enough',
#  'woo ed harris he was great as mccain',
#  'yeah eddie redmayne was at the golden globes i die ugh',
#  '“: pretty much the only way the golden globes could be interesting at all to me is if i won one”\n\nha',
#  'i love the people reacting to golden globes tweeting like theyve never seen twitter before what youre looking for is called',
#  'rt : every time robert downey jr is on screen hes joking with someone else xd i love this man',
#  'rt : theres alot of steroids up on stage right now',
#  'rt : its starting',
#  'bill clinton is the new al gore',
#  'martín fierro de oro &gt;&gt;&gt; gol de oro &gt;&gt;&gt; balón de oro &gt;&gt;&gt; golden globes',
#  's stereotype du (manymany)jours rt : never underestimate caricatures of scary bearded muslim mobs',
#  '😍😍',
#  'very chanel what anne hathaways wearing like like like',
#  'creator of homeland i too wish i could see an 8mths pregnant claire danes being chased with a pipe',
#  'you look amazing favorite dress of the night',
#  'oh por dios les misérablesmejor película en los  ganará el oscar también ♪♫♪',
#  'best motion picture drama: argo  -- congrats',
#  'the end roll credits the golden globes are nominated for an emmy for best variety show',
#  'rt : anne hathaway is absolutely beautiful',
#  'well that is it lincoln for the lock  gg and oscar  i can go to sleep now until next season bye',
#  'and fuck you idiots at the academy heres to a billion middle fingers for overlooking ben affleck',
#  'la bellísima kate hudson  2013',
#  'i trust a man with a beard  seriously',
#  'taylor swift on a un peu la haine on dirait',
#  'wolverine wins for singing',
#  'i talk smack but i have no idea what kinda speech i would make bed time for me and my sick body',
#  'rt : hatfields and mccoys wins with kevin costner',
#  'desde já agradecendo a todos tradutores simultaneos por fazerem eu perder qualquer provável piadinha do golden globes',
#  'rt : mi resperto y admiración para jodie : dramática y sexy y tiene 50 añ',
#  'can we stop the live tweeting about the   no one gives a shit',
#  'this anti-smoking commercial will haunt my dreams',
#  'rt : what were secretly thinking during all of these red carpet interviews: ok but where is ryan gosling',
#  'off to work enjoy the rest of the gold plated but really not even that globe awards',
#  'i get it hollywood you have to butt kiss but keep the speeches short or make it',
#  'really happy taylor swift didnt win :d',
#  'i never even saw lucy liu sneaking into my house and stealing my bedspread shes quick',
#  'rt : these ladies are taking no prisoners amy poehler and tina fey are great on this opening',
#  'rt : in terms of hair tonight i am going for jewish morrissey',
#  'our fantine is sweeping this award season mark my words',
#  'time to look forward to  after party pictures~',
#  'i missed the red carpet segment can anyone fill me on on the best legs and booty',
#  'omg i love tina fey and any polher dressing up as actors who arent at the',
#  'costner = aging well also = boring where are tina and amy',
#  'rt :  youve got another winner congratulations to claire danes &amp;',
#  'love people and stay beside them - jodie foster',
#  'el batacazo de la noche ben affleck como mejor director por “argo”',
#  'sorry golden globes west wing is better',
#  'amy poehler and tina fey are killin it',
#  'i wish i was an actress and go to the golden globes',
#  'rt : ninguém merecia mais esse prêmio que a lena dunham e olha que eu amo todas as outras indicadas ”',
#  'wow bill clinton',
#  'i have no idea what jodie foster just said',
#  'wheres the guy who played fdr  in fdr: american basdass  thats how you know this is fake',
#  'rt :  a que maldita hora deje de ver homeland',
#  'bill clinton presentando lincoln en los   esto suena a victoria cantada ¿no',
#  'lena dunham--word of advice; flats',
#  'best television series - drama -  -',
#  'jodie foster me hace llorar:) dios mil que bella &lt;3',
# ...
#  'adele no es conformista tiene hambre de más',
#  'rt :  : les miserables wins best motion picture get i &lt;3 jean valjean tshirt  : :',
#  'whoops i mistook eva longoria for a kardashian and cursed her',
#  'definitely digging lucy lius dress very pretty',
#  'what the fuck is the golden globes',
#  'they censored/bleeped out her actual coming out part i guess it was a good few seconds no idea',
#  'watching the  right now--loved tina fey &amp; amy poehlers hilarious opening ive actually been in that ballroom before for tca',
#  'photoset: xjapanx: from the golden globes 2013',
#  'rt : deçu pour intouchables qui selon moi aurait du gagner le meilleur film de langue etrangere',
#  'maggie smith se lleva el  por su papel en downton abbey de pbs',
#  'rt : diablo dos siglos parados en los golden globes',
#  'rt : en attendant les golden globes 2013 la liste complète des nommés en cinéma',
#  'who put rdj and mel gibson together party table much',
#  'im basically watching the \xa0through tweets dont we all just love social networks',
#  'rt : icymi: jodie fosters moving &amp; beautiful  speech [watch] --&gt;',
#  'i think i could make a killing moving to la to teach girls to walk in heels',
#  'les organisateur de galas au qc devraient sinspirer du rythme des galas américains',
#  'golden globes make-up',
#  'im damn surprised and im happy to be surprised - quentin tarantino',
#  'new love for jody foster   &lt;3',
#  'rt : something about a hamster',
#  'okay vanessa hudgens and selena gomez look fab for the golden globes',
#  'say sofia vergara one more',
#  'rt : finalmente vai começar',
#  'jodie foster is the greatest',
#  'i am done now',
#  'yay for damien lewis and homeland',
#  'rt : yes well done to claire danes such an amazing actress check her out in stardust too',
#  'rt : how can i make this  viewing about me',
#  'rt : this hair color on kristen wiig is perfect',
#  'rt  homeland wins the best tv series drama  rt if you think it is well deserved',
#  'tarantinoooooooo',
#  'love the white on anne hathaway',
#  'rt : paul rudd still making us swoon since  in 95',
#  'uh dan hathaway how bout we take that one again catherine',
#  'my lucky brooklyn whiskey paid off for',
#  'golden globes live over breakfast in singapore',
#  'argo schmargo ben matt damon went and bought a zoo and shit top that',
#  'pats win 1ds in africa doing charity stuff les mis is gonna sweep at the golden globes',
#  'rt : megan fox how did you just have a baby a few months ago',
#  'from  w/ben affleck on set of argo argo won best picture on golden globes tonight',
#  'give catherine zeta jones everything for that movie intro',
#  'wait bill clinton takes the stage at the  ♥',
#  'anne hathaway i love the bathmat and towel you chose to wear to the',
#  'my favorite part of golden globes the end when the announcer says this is shawn parr  hes a real bowler',
#  'the golden globes used a polo song oh no',
#  'does this mean we are going to have to suffer with brody for another three seasons',
#  'homeland is making the golden globes their bitch lol',
#  'check bill clinton out lol',
#  'sorry  but  &amp;  come on tonight and they new episodes i must tune in to my shows',
#  'golden globes or downtown abby  thanks to my vacation time i am hooked on downtown abby such a good show',
#  'i adore adele so much :-)',
#  'rt : ann hathaway went from princess diaries to winning golden globes u go bitch',
#  'aziz aziz like so funny',
#  'rt : when did the whole world decide to love the golden globes so much',
#  'golden globes; tina &amp; amy are already kicking ass &amp; as always hilarious',
#  'unlike other awards in the  the celebrities only go to eat and do not win awards',
#  'and eva longoria has  exactly since leaving desperate housewhores',
#  'mi novio rob en  &lt;3',
#  'rt : whoa  just said i still live in philly',
#  'bill clinton at the  - awesome',
#  'q los hombres esten vestidos igual en los  no importa pero q sean 2 mujeres con el mismo vestido',
#  'please keep the camera on amanda seyfried thanks',
#  'rt : que discurso foda jodie',
#  'maybe i am the only one watching but i hate lucy luiss dress the emcees seem to love it who knows',
#  'life of piiiiiiiiiii',
#  'rt : quentin tarantino wins for djimon hounsou unchained',
#  'and hathaway wipes her nose and thanks her manager - its getting loose in here',
#  'and the nip slip will go to--eva longoria that being said that dress is fucking gorgeous',
#  'rt : fact: bill clinton has had sex with over 90% of the women in that room',
#  'your crush may grow when you find out she has the flu',
#  'the show girls won the   great kick off for its 2nd season premiere',
#  'rt :  red carpet trends: leg bombing is back pics: ://',
#  'yay  wins at the  for  (and the season premiere was on tonight big night)',
#  'well deserved win for lena',
#  'taylor swift wasnt pissed you guys thats just her face her squinty\nadolescent face',
#  'lo único que espero de los  es fashion police',
#  'i absolutely love claire danes',
#  'mais um cabelo propaganda de shampoo',
#  'you think its awkward for other actors when mel gibson shows up',
#  'jodie foster is god',
#  'el gran ausente de los  fue el  megacable',
#  'rt : i found the comforter that i got for my wedding 21 years ago goldenglobess photo',
#  ': anne agradeciendo la inspiración de sally field  se puede ser más adorable   :)',
#  'will ferrel and kristin wig stop being so perfect',
#  'my nights already complete seeing hugh jackman and nathan fillion on golden globes',
#  'rt : i never thought it would happen heres the speech i wrote in advance though - lena dunham just being lena',
#  'quando si parla di tortura mi fido di una donna che è stata sposata con  per tre anni',
#  'wow-not a dry eye in the room what did you think of s  acceptance speech',
#  'pronto já vi golden globes ja vi girls vou tomar banho e dormir pra enfrentar a semana',
#  'rt : golden globes didnt get the memo 2013 is the year of swift',
#  'argo best motion picture of the year =d buenisiiima pelicula',
#  'chegou a hora mais esperada prêmio cecil b demille para a sapa luxo-poder-e-cobiça jodie foster',
#  'ed harris beat indigo montoya boo',
#  'rt : the only thing more entertaining than watching  on  is the',
#  '-´- devio ganar the new girl schmidth',
#  'rt : girls if you want to work in hollywood dont paint you body permanently',
#  'for once i want somebody to go up there and be like yeah i was gonna win',
#  'i know i had pancakes for breakfast but i would schmeer maple syrup all over j los jell-o if ya know what i',
#  'speaking of anne hathaway was the dark knight rises up for any',
#  'golden globes my favorite ladies',
#  'recordingg da golden globes',
#  'yup',
#  'rt : ellos dicen maggie smith nosotros pensamos profesora mcgonagall',
#  'watching the golden globes with my parents we are keeping score on how many of our favorite nominees win',
#  'rt :  -  winner for best motion picture - drama huge congrats to director  and the entire cast and crew',
#  'lol i wonder if marlon williams is at the golden globes tweeting lol',
#  'tarantino vencedor de melhor roteiro tudo está bem agora',
#  'i would love to watch the golden globes but the family guy is on  just sayin',
#  'i was about to watch the golden globes but the hunger games is going on so yeah cant',
#  'rt : youre supposed to walk on it',
#  'rt : were live blogging the',
#  'tina + amy = melhores piadas ever',
#  'tina and amy youre both hot',
#  'will ferrell &amp; kristen wigg serious killed me',
#  'かわいいなー^^ rt : these two people look very happy congrats anne hathaway amanda seyfried and …',
#  'rt : selena esta usando un vestido de atelier versace spring 2012 los golden globes awards 2013  ¿les gusta',
#  'rt : best supporting actress in a motion picture:  anne hathaway for les mis',
#  'if anyone wants to create a meet up group that hunts the hathaway for sport im in',
#  'golden globes with amandawana &amp; swov they chose the foods dino nuggets bagel bites @ the wanamaker abode',
#  'rt : anne hathaway - les miserables mejor actriz de reparto',
#  'cant stop staring at sofias cleavage she has some very',
#  'yikes alyssa',
#  'i beat meryl jennifer lawrence is my hero can we be best friends',
#  'svu &gt;&gt;&gt;&gt;&gt; golden globes',
#  'rt : i love les mis i love musical theatre i love broadway i love this entire cast well deserved win  🎭🏆',
#  'je nai quun seul mot :',
#  'i think somebody rubbed a balloon on kate hudsons head',
#  'best musical score goes to life of pi  thanks mom and dad for the gift of music that you gave me',
#  'rt : here are all the winners from the 2013 golden globes congrats to all the winners ://',
#  'im scared what julia roberts will do when she realizes shes not giving an award to denzel',
#  'rt“: every time they show matt lauer i think i hate you and where is anne curry my issue watching ”',
#  'god why are the people at te golden globes so pretty',
#  'wait what time are the',
#  'our next presenter is so good looking he makes young george clooney look like garbage please welcome george clooney',
#  'you need some me time to learn about yourself - tina fey on taylor swifts love life yes',
#  'oh what does it say i beat meryl jennifer lawrence is the best',
#  'yay anne hathaway best fantine',
#  'bradley coopers sucha cutie',
#  'i love the   go',
#  'pulls an angelina jolie (2013 golden globes',
#  'jennifer saving bens ass  lol',
#  'wow claire danes amazing body',
#  'ben affleck  mejor película  hellow academia a por el culo a los oscar  the best',
#  'on the night the second season airs  cleans up',
#  'kate hudsons dress wow best dressed by far',
#  'yayyyyyyyyyyyyyy hugh jackmannnnnnnn aaaaaggghhh aagghh',
#  'of course ben affleck is from boston; that look was just as serious as belichicks game face',
#  'congratulations \xad jennifer lawrence for silver linings playbook',
#  'rt : y el  al mejor actor de comedia o musical es para… ¡hugh jackman por',
#  'rt : the girl who started as the princess of genovia - anne hathaway on overcoming being typecast fantine wins',
#  'rt : ok i give kristen wiig and will ferrell are making me cry laughing between them and poehler/fey first watchable golden globes ever',
#  'el coraje es ser honesto con uno mismo',
#  'rt : a la 1 termina  ojala que glee tambn empiese a la 1',
#  'rt : counting down to the adele high fiving daniel craig gifs',
#  'solid   surprised and excited about argo rockin its categories',
#  'rt : best motion picture - drama - argo -  // con todo ben affleck',
#  'rt : how chic are mr and miss golden globes',
#  'anne e amanda comemorando fofaaaas demais',
#  '«ονειρευόμουν ότι θα ήμουν πολύ πιο cool αν αυτό μου συνέβαινε και δεν είμαι» μονο για αυτο σε συμπαθησα λενα νταναμ',
#  'joke of the year from amy poehler when it comes to torture i trust the lady who spent three years married to james cameron',
#  'maggie smith steals supporting actress statue at golden globes',
#  'lmfao rt taylor swift is going to write a song about tina fey now',
#  'jodie foster 50 she can not be',
#  'reckless botox abounds at',
#  'y el globo de oro de la mejor pelicula de fraudenarcotrafico y saqueo es',
#  'the  is the one award show i would definitely want to be at',
#  'anne hathaway in chanel golden globes 2013 red',
#  'rt : kate hudson was also one of my best dressed at the',
#  'rt : adivinen quién se ve más guapa rt : selena gomez vanessa hudgens &amp; heidi klum',
#  'golden globes: ‘ homeland’ wins for drama series actor in a drama',
#  'is austrian  is an austrian movie hmmm',
#  'jlaw won lol',
#  'i love the golden globes drunk in a tux is always classy',
#  'rt : that awkward  moment you ask hannibal lecter who he is wearing',
#  'the zero dark thirty music score is oddly reminiscent of the imperial death',
#  'anne hathaway long in the tooth christoph waltz long in the chin',
#  'damn eva longoria looks great at the golden globes',
#  'aquí casual viendo los golden globes por',
#  'ugh why is season 2 of  on at the same time as the  why must you make me choose like that',
#  'woooooo ben afleck wins  woooooooo',
#  'rt : what happened to tina and amy being them back',
#  'best performance of the year: eugene levy as mandy patinkin as saul berenson',
#  '“: jessica chastain still catching her breathe after the win  ” my favorite speech',
#  'rt : watching the golden globes is giving me prom dress ideas',
#  'no body can beat  sorry but its true',
#  'apparently tommy lee jones doesnt agree',
#  'golden globes is an anagram of go go bell ends',
#  'rt : cutest moment yet  high fives daniel craig after winning  for best original score forskyfall',
#  'not a fan of lucy lius',
#  'is intelligent beautiful  id cross over for her',
#  'hayden panettieres acting is not the best of anything ever',
#  'shit missing the golden globes',
#  'whats the point of watching the golden globes',
#  'melhor atriz em série de humor ou musical: lena dunham por girls',
#  'rt : denzel washington looks great as usual',
#  'what category did they just screw up cause that skit sucked  is killing the   bring back gervais',
#  'amour gana el oscar a mejor película extranjera en  un presagio de lo que será en los próximos premios oscar',
#  'i absolutely adore her brilliant in every movie shes in jessica',
#  'golden globe awards: halle berry: halle berry wasnt afraid to show a little skin - and show off an amazing set',
#  'anne hathaway 👏',
#  'thrilled for jennifer lawrence well deserved now all i need is that red dress',
#  'ok tina and',
#  'awww estan geniales los',
#  'why must bill clinton do everything he doesnt belong at the golden globes',
#  'ahahaahahahhah tina slagging taylor swift  why did the camera not pan to her excellent',
#  'why isnt hugh jackman singing his acceptance speech',
#  'as i think about it i think i should watch the golden globes',
#  'ok:( rt :   deja el drama que no te van a dar un  bájale dos',
#  'tina and amy just announced theyre going home with lady edith',
#  'will ferrell and kristen wiig should host next year',
#  'love the hottie taking a bottle of champagne to the face behind dame helen mirren',
#  'i want to cry i cant see benedict on the golden globes bc ouat is on and i dont have a dvr anymore 💔',
#  'rt : taylor swift looked pissed when they cut to her after losing',
#  'rt :  anne hathaway wins for best supporting actress motion picture for les miserables  i shall now wallow in my crush',
#  'finally somebody that can bring some true comedy into this boring',
#  'y en solo 10 minutos amy poehler y tina fey le quitan el puesto a ricky gervais como el mejor anfitrión de los golden globes',
#  'hauahuahauhuahauaha a plateia toda oooooooooooh quando a tina falou da taylor swift',
#  'its official  amy poehler and tina fey must host the  every year',
#  'seriously lena dunham  is garbage amy and tina are far more deserving',
#  'la verdad no se me hizo tan cool argo para que ganara',
#  'jimmy is my absolute favorite',
#  'rt : a cerimônia de premiação do globo de ouro começa em instantes confira a cobertura ao vivo:',
#  'rt : game change gana mejor mini serie o película para televisión',
#  'rt : yes christoph waltz',
#  'rt : it took me a while to look away from how shiny jlo is but when i did wow: trashy wedding barbie wants her dress back',
#  'rt : er reunion on the golden globes red carpet: george clooney julianna margulies hug (video): it was an er ://',
#  'el amour se hace presente en los  como mejor película extranjera',
#  'rt : youre welcome affleck : argo-makers thank us foreign service in their thank you speech keepin it classy',
#  'rt : tonight we are all julia louis-dreyfus',
#  'i wish meryl was thereeee',
#  'rt : ben affleck claims the best director prize at the  for argo:',
#  'rt : can tony stark i mean robert downey jr walk the red carpet',
#  'mañana en clase me voy a acordar de los golden globes y de muy mala manera jajaj',
#  'rt : golden globes given by hollywood *foreign* press; their judgments have no effect on sovereign us cultural preferences',
#  'holy crap president bill clinton',
#  'dont worry cumberbatch by sherlock series 3 youll be a household name &amp; will have it in the bag',
#  'rt : my mom is making me make dinner and i cant fuckin see the screen',
#  ...]

# %%
df = pd.DataFrame(s, columns=['text'])
print(len(df))
df.head()
# Out:
# 122130
#                                                                                                   text
# 0
# 1                                         amy poehler y george clooney seria la mejor pareja del mundo
# 2                  rt : best supporting actress in a motion picture - anne hathaway - les miserables -
# 3  i gots to drop you buddy  love your political stuff but i cant have you doing golden globes play...
# 4                                              “: jlo is looking like sex at the golden globes 😍”truth

# %%
df = df.loc[df['text'].str.contains('host')]
print(len(df))
df.head()
# Out:
# 1652
#                                                                                                     text
# 20   rt : jodie foster claire danes &amp; lea michele tina and amy as hosts les mis etc etc one of th...
# 100             tina fey and amy phoehler are killing it as hosts of the golden globes dont you think so
# 120                                         so are you getting ideas for your future hosting job tonight
# 175                                                 tina faye and amy polar hosting the golden globes 😂👍
# 315                         amy &amp; tina are making everyone laugh they are the best hosts for the  :)

# %%
def nGram(text):
    test = text
    firstsplit = test.split(' hosts ', 1)
    if len(firstsplit) > 1:
        left = firstsplit[0].split(' ')
        left.reverse()
        right = firstsplit[1].split(' ')
        new_list = []
        x = ""
        for i in left:
            x =  i + x + ' '
            new_list.append(x)
        x = ""
        for i in right:
            x = x + i + ' '
            new_list.append(x)
        new_list = [x.rstrip() for x in new_list]
    else:
        new_list = []
    return new_list

# %%
FINAL_NGRAMS = []
NGRAMS_DICT = {}
for i in range(len(df)):
    
    l = nGram(df['text'].iloc[i])
    for j in l:
        if j in NGRAMS_DICT:
            NGRAMS_DICT[j] += 1
        else:
            NGRAMS_DICT[j] = 1

# %%
cd = sorted(NGRAMS_DICT.items(),key=operator.itemgetter(1),reverse=True)
cd
# Out:
# [('best', 63),
#  ('the', 62),
#  ('ever', 51),
#  ('', 49),
#  ('for', 40),
#  ('as', 35),
#  ('thebest', 35),
#  ('tina', 33),
#  ('of', 32),
#  ('tina fey', 30),
#  ('globes', 28),
#  ('goldenglobes', 28),
#  ('of the', 21),
#  ('next', 21),
#  ('arethebest', 20),
#  ('tina fey amy', 18),
#  ('wiig', 16),
#  ('willferrellandkristenwiig', 16),
#  ('kristenwiig', 15),
#  ('andkristenwiig', 15),
#  ('ferrellandkristenwiig', 15),
#  ('next year', 14),
#  ('tina fey and amy poehler', 14),
#  ('for the', 13),
#  ('great', 13),
#  ('tina fey and', 12),
#  ('of the golden', 11),
#  ('years', 11),
#  ('tina fey and amy', 11),
#  ('nextyears', 10),
#  ('are', 10),
#  ('to', 10),
#  ('of the golden globes', 9),
#  ('2014', 9),
#  ('for the golden', 9),
#  ('for the golden globes', 9),
#  ('tina fey amy poelhers', 9),
#  ('tina fey amy poelhers opening', 9),
#  ('tina fey amy poelhers opening monologue', 9),
#  ('tina fey amy poelhers opening monologue is', 9),
#  ('tina fey amy poelhers opening monologue is a', 9),
#  ('tina fey amy poelhers opening monologue is a sexual', 9),
#  ('amazing', 8),
#  ('the golden', 8),
#  (':', 8),
#  ('canwealljustagreethatamyandtinaarethebest', 8),
#  ('at the', 8),
#  ('so', 7),
#  ('tinaarethebest', 7),
#  ('andtinaarethebest', 7),
#  ('amyandtinaarethebest', 7),
#  ('tina fey amy poehlers', 7),
#  ('tina fey amy poehlers opening', 7),
#  ('tina fey amy poehlers opening monologue', 7),
#  ('tina fey amy poehlers opening monologue is', 7),
#  ('tina fey amy poehlers opening monologue is a', 7),
#  ('tina fey amy poehlers opening monologue is a sexual', 7),
#  ('kristenwiigandwillferrellas', 7),
#  ('to ever', 7),
#  ('our', 7),
#  ('better', 7),
#  (':willferrellandkristenwiig', 7),
#  ('so far', 6),
#  (' &amp;', 6),
#  ('tina fey amy poelhers opening monologue is a sexual nightmare:', 6),
#  ('tina fey amy poehlers opening monologue is a sexual nightmare:', 6),
#  ('the golden globes', 6),
#  ('ferrellas', 6),
#  ('willferrellas', 6),
#  ('for 2014', 6),
#  ('show', 6),
#  ('for next', 6),
#  ('“:willferrellandkristenwiig', 6),
#  ('next year”', 6),
#  ('hilarious', 6),
#  ('thatamyandtinaarethebest', 6),
#  ('agreethatamyandtinaarethebest', 6),
#  ('justagreethatamyandtinaarethebest', 6),
#  ('alljustagreethatamyandtinaarethebest', 6),
#  ('wealljustagreethatamyandtinaarethebest', 6),
#  ('to ever grace', 6),
#  ('to ever grace an', 6),
#  ('to ever grace an awards', 6),
#  ('to ever grace an awards show', 6),
#  ('to ever grace an awards show stage', 6),
#  ('at', 6),
#  ('itas', 5),
#  ('killingitas', 5),
#  ('amyarethebest', 5),
#  ('andamyarethebest', 5),
#  ('tinaandamyarethebest', 5),
#  ('asthe', 5),
#  ('tinaas', 5),
#  ('tina fey amy poelhers opening monologue is a sexual nightmare: \nquentin',
#   5),
#  ('andwillferrellas', 5),
#  ('wiigandwillferrellas', 5),
#  ('hollywood', 5),
#  ('have', 5),
#  ('whydothegoldenglobesevenhave', 5),
#  ('poehleras', 5),
#  ('amypoehleras', 5),
#  ('i', 5),
#  ('in', 4),
#  ('andtinaas', 4),
#  ('amyandtinaas', 4),
#  ('tothe', 4),
#  ('rt:', 4),
#  ('for next year', 4),
#  ('funny', 4),
#  ('bestgoldenglobes', 4),
#  ('thebestgoldenglobes', 4),
#  ('arethe', 4),
#  ('werethebest', 4),
#  ('de', 4),
#  ('wiigfor', 4),
#  ('rt:willferrellandkristenwiig', 4),
#  ('weregreat', 4),
#  ('evenhave', 4),
#  ('andamypoehleras', 4),
#  ('feyandamypoehleras', 4),
#  ('tinafeyandamypoehleras', 4),
#  ('tina fey and amy poehler arrive at the', 4),
#  ('fornextyears', 4),
#  ('amyandtinaweregreat', 4),
#  ('arekillingitas', 3),
#  ('greatest', 3),
#  ('in the', 3),
#  ('in the history', 3),
#  ('in the history of', 3),
#  ('ofthe', 3),
#  (' no', 3),
#  ('tina fey amy poelhers opening monologue is a sexual nightmare: \nquentin ://',
#   3),
#  ('rt:kristenwiigandwillferrellas', 3),
#  ('anddidanamazingjobbest', 3),
#  ('awardshow', 3),
#  ('on', 3),
#  ('of all', 3),
#  ('good', 3),
#  ('amy', 3),
#  ('was', 3),
#  ('-tinaandamywerehilarious', 3),
#  ('and', 3),
#  ('awardsshow', 3),
#  ('pickedbetter', 3),
#  ('havepickedbetter', 3),
#  ('tina fey amy poelhers opening monologue is a sexual nightmare', 3),
#  ('aregreat', 3),
#  ('globesevenhave', 3),
#  ('goldenglobesevenhave', 3),
#  ('thegoldenglobesevenhave', 3),
#  ('dothegoldenglobesevenhave', 3),
#  ('tina and', 3),
#  ('tina and amy', 3),
#  ('tina and amy have', 3),
#  ('tina and amy have been', 3),
#  ('tina and amy have been on', 3),
#  ('tina and amy have been on for', 3),
#  ('tina and amy have been on for like', 3),
#  ('tina and amy have been on for like 47', 3),
#  ('tina and amy have been on for like 47 seconds', 3),
#  ('tina and amy have been on for like 47 seconds this', 3),
#  ('tina and amy have been on for like 47 seconds this entire', 3),
#  ('tina and amy have been on for like 47 seconds this entire evening', 3),
#  ('tina fey and amy poehler have', 3),
#  ('tina fey and amy poehler have graciously', 3),
#  ('tina fey and amy poehler have graciously provided', 3),
#  ('tina fey and amy poehler have graciously provided a', 3),
#  ('tina fey and amy poehler have graciously provided a golden', 3),
#  ('tina fey and amy poehler have graciously provided a golden globes', 3),
#  ('tina fey and amy poehler have graciously provided a golden globes drinking',
#   3),
#  ('tina fey and amy poehler have graciously provided a golden globes drinking game',
#   3),
#  ('tina fey and amy poehler have graciously provided a golden globes drinking game bottoms',
#   3),
#  ('tina fey and amy poehler have graciously provided a golden globes drinking game bottoms up',
#   3),
#  ('tina fey and amy poehler have graciously provided a golden globes drinking game bottoms up |',
#   3),
#  ('itsour', 3),
#  (':itsour', 3),
#  ('im', 3),
#  ('see', 3),
#  ('tonight', 3),
#  ('arethisyears', 3),
#  ('&amp;-best', 3),
#  ('should be tina fey and amy poehler', 3),
#  ('theyarethebest', 2),
#  ('poehlerarethebest', 2),
#  ('amypoehlerarethebest', 2),
#  ('andamypoehlerarethebest', 2),
#  ('feyandamypoehlerarethebest', 2),
#  ('tinafeyandamypoehlerarethebest', 2),
#  ('that', 2),
#  ('for2014', 2),
#  ('wiigfor2014', 2),
#  ('kristenwiigfor2014', 2),
#  ('andkristenwiigfor2014', 2),
#  ('ferrellandkristenwiigfor2014', 2),
#  ('willferrellandkristenwiigfor2014', 2),
#  ('maybewillferrellandkristenwiigfor2014', 2),
#  ('thatmaybewillferrellandkristenwiigfor2014', 2),
#  ('scratchthatmaybewillferrellandkristenwiigfor2014', 2),
#  (':scratchthatmaybewillferrellandkristenwiigfor2014', 2),
#  ('amygreatest', 2),
#  ('tinaamygreatest', 2),
#  ('in the history of the', 2),
#  ('in the history of the golden', 2),
#  ('in the history of the golden globes', 2),
#  ('thinkofthe', 2),
#  ('youthinkofthe', 2),
#  ('doyouthinkofthe', 2),
#  ('whatdoyouthinkofthe', 2),
#  ('offwhatdoyouthinkofthe', 2),
#  ('thingsoffwhatdoyouthinkofthe', 2),
#  ('kickedthingsoffwhatdoyouthinkofthe', 2),
#  ('havekickedthingsoffwhatdoyouthinkofthe', 2),
#  ('poehlerhavekickedthingsoffwhatdoyouthinkofthe', 2),
#  ('amypoehlerhavekickedthingsoffwhatdoyouthinkofthe', 2),
#  ('andamypoehlerhavekickedthingsoffwhatdoyouthinkofthe', 2),
#  ('feyandamypoehlerhavekickedthingsoffwhatdoyouthinkofthe', 2),
#  ('tinafeyandamypoehlerhavekickedthingsoffwhatdoyouthinkofthe', 2),
#  ('feyarethebest', 2),
#  ('tinafeyarethebest', 2),
#  ('andtinafeyarethebest', 2),
#  ('bethe', 2),
#  ('of everything', 2),
#  ('right', 2),
#  ('women', 2),
#  ('seethe', 2),
#  ('isrightdidthe', 2),
#  ('ifthe', 2),
#  ('wouldbealotmoreentertainingifthe', 2),
#  (':the', 2),
#  ('rt:the', 2),
#  ('not', 2),
#  ('or', 2),
#  ('tina fey amy poehlers opening monologue is a sexual nightmare: \njames', 2),
#  ('tina fey amy poehlers opening monologue is a sexual nightmare: \njames cameron',
#   2),
#  ('especiallyas', 2),
#  ('the golden globes have', 2),
#  ('fayarethebest', 2),
#  ('tinafayarethebest', 2),
#  ('andtinafayarethebest', 2),
#  ('poehlerandtinafayarethebest', 2),
#  ('amypoehlerandtinafayarethebest', 2),
#  ('omgamypoehlerandtinafayarethebest', 2),
#  ('forgoldenglobes', 2),
#  (':kristenwiigandwillferrellas', 2),
#  ('the golden globes:', 2),
#  ('the golden globes: a', 2),
#  ('the golden globes: a host', 2),
#  ('the golden globes: a host of', 2),
#  ('the golden globes: a host of stars', 2),
#  ('the golden globes: a host of stars are', 2),
#  ('the golden globes: a host of stars are attending', 2),
#  ('the golden globes: a host of stars are attending the', 2),
#  ('the golden globes: a host of stars are attending the golden', 2),
#  ('the golden globes: a host of stars are attending the golden globes', 2),
#  ('the golden globes: a host of stars are attending the golden globes in', 2),
#  ('the golden globes: a host of stars are attending the golden globes in hollywood',
#   2),
#  ('the golden globes: a host of stars are attending the golden globes in hollywood with',
#   2),
#  ('the golden globes: a host of stars are attending the golden globes in hollywood with maggie',
#   2),
#  ('didanamazingjobbest', 2),
#  ('asfunny', 2),
#  ('&amp;asfunny', 2),
#  ('alreadythebestgoldenglobes', 2),
#  ('arealreadythebestgoldenglobes', 2),
#  ('poehlerarealreadythebestgoldenglobes', 2),
#  ('amypoehlerarealreadythebestgoldenglobes', 2),
#  ('&amp;amypoehlerarealreadythebestgoldenglobes', 2),
#  ('fey&amp;amypoehlerarealreadythebestgoldenglobes', 2),
#  ('tinafey&amp;amypoehlerarealreadythebestgoldenglobes', 2),
#  ('amy poehler', 2),
#  ('amy poehler and', 2),
#  ('amy poehler and tina', 2),
#  ('wherearethe', 2),
#  ('we', 2),
#  ('for golden globes 2014', 2),
#  ('bringthe', 2),
#  ('de los', 2),
#  ('now:best', 2),
#  ('itnow:best', 2),
#  ('callitnow:best', 2),
#  ('justcallitnow:best', 2),
#  ('wejustcallitnow:best', 2),
#  ('canwejustcallitnow:best', 2),
#  ('okcanwejustcallitnow:best', 2),
#  ('feyokcanwejustcallitnow:best', 2),
#  ('tinafeyokcanwejustcallitnow:best', 2),
#  ('-tinafeyokcanwejustcallitnow:best', 2),
#  ('nightmares-tinafeyokcanwejustcallitnow:best', 2),
#  ('sexualnightmares-tinafeyokcanwejustcallitnow:best', 2),
#  ('mysexualnightmares-tinafeyokcanwejustcallitnow:best', 2),
#  ('allmysexualnightmares-tinafeyokcanwejustcallitnow:best', 2),
#  ('ofallmysexualnightmares-tinafeyokcanwejustcallitnow:best', 2),
#  ('starofallmysexualnightmares-tinafeyokcanwejustcallitnow:best', 2),
#  ('thestarofallmysexualnightmares-tinafeyokcanwejustcallitnow:best', 2),
#  ('herethestarofallmysexualnightmares-tinafeyokcanwejustcallitnow:best', 2),
#  ('isherethestarofallmysexualnightmares-tinafeyokcanwejustcallitnow:best', 2),
#  ('tarantinoisherethestarofallmysexualnightmares-tinafeyokcanwejustcallitnow:best',
#   2),
#  ('quentintarantinoisherethestarofallmysexualnightmares-tinafeyokcanwejustcallitnow:best',
#   2),
#  ('“:canwealljustagreethatamyandtinaarethebest', 2),
#  ('to ever grace an awards show stage ”', 2),
#  ('foundour', 2),
#  ('for next years', 2),
#  (':canwealljustagreethatamyandtinaarethebest', 2),
#  ('about', 2),
#  ('excitedabout', 2),
#  ('soexcitedabout', 2),
#  ('getsoexcitedabout', 2),
#  ('dontgetsoexcitedabout', 2),
#  ('-dontgetsoexcitedabout', 2),
#  ('all-dontgetsoexcitedabout', 2),
#  ('usall-dontgetsoexcitedabout', 2),
#  ('tousall-dontgetsoexcitedabout', 2),
#  ('lessontousall-dontgetsoexcitedabout', 2),
#  ('alessontousall-dontgetsoexcitedabout', 2),
#  ('bealessontousall-dontgetsoexcitedabout', 2),
#  ('thisbealessontousall-dontgetsoexcitedabout', 2),
#  ('letthisbealessontousall-dontgetsoexcitedabout', 2),
#  ('of these', 2),
#  ('of these shows', 2),
#  ('of these shows because', 2),
#  ('of these shows because we', 2),
#  ('of these shows because we hardly', 2),
#  ('of these shows because we hardly get', 2),
#  ('of these shows because we hardly get to', 2),
#  ('of these shows because we hardly get to see', 2),
#  ('of these shows because we hardly get to see them', 2),
#  ('andwiigfor', 2),
#  ('ferrellandwiigfor', 2),
#  (':ferrellandwiigfor', 2),
#  ('rt:ferrellandwiigfor', 2),
#  ('feyarethe', 2),
#  ('tinafeyarethe', 2),
#  ('thisshowhas', 2),
#  ('nothavepickedbetter', 2),
#  ('couldnothavepickedbetter', 2),
#  (':couldnothavepickedbetter', 2),
#  ('rt:couldnothavepickedbetter', 2),
#  ('at the  = success', 2),
#  ('rtcanwealljustagreethatamyandtinaarethebest', 2),
#  ('canrtcanwealljustagreethatamyandtinaarethebest', 2),
#  ('wecanrtcanwealljustagreethatamyandtinaarethebest', 2),
#  ('news:goldenglobes', 2),
#  ('they', 2),
#  ('thisyearthe', 2),
#  ('had', 2),
#  ('had a lot to do w/ that looking forward to the', 2),
#  ('had a lot to do w/ that looking forward to the  &amp;', 2),
#  ('feyweregreat', 2),
#  ('tinafeyweregreat', 2),
#  ('andtinafeyweregreat', 2),
#  ('poehlerandtinafeyweregreat', 2),
#  ('amypoehlerandtinafeyweregreat', 2),
#  ('such', 2),
#  ('such a', 2),
#  ('such a good', 2),
#  ('such a good golden', 2),
#  ('such a good golden globes', 2),
#  ('such a good golden globes and', 2),
#  ('such a good golden globes and everyone', 2),
#  ('such a good golden globes and everyone who', 2),
#  ('such a good golden globes and everyone who won', 2),
#  ('such a good golden globes and everyone who won deserves', 2),
#  ('such a good golden globes and everyone who won deserves it', 2),
#  ('rtwhydothegoldenglobesevenhave', 2),
#  ('yuprtwhydothegoldenglobesevenhave', 2),
#  ('since', 2),
#  ('ever i', 2),
#  ('rt:itsour', 2),
#  ('reallygotbacktotherootofclassy&amp;entertainingawesome', 2),
#  ('were', 2),
#  ('wereas', 2),
#  ('poehlerwereas', 2),
#  ('amypoehlerwereas', 2),
#  ('andamypoehlerwereas', 2),
#  ('feyandamypoehlerwereas', 2),
#  ('tinafeyandamypoehlerwereas', 2),
#  ('brillianttinafeyandamypoehlerwereas', 2),
#  ('howbrillianttinafeyandamypoehlerwereas', 2),
#  ('knowinghowbrillianttinafeyandamypoehlerwereas', 2),
#  ('im dreading', 2),
#  ('im dreading seth', 2),
#  ('im dreading seth macfarlanes', 2),
#  ('im dreading seth macfarlanes gig', 2),
#  ('im dreading seth macfarlanes gig even', 2),
#  ('im dreading seth macfarlanes gig even more', 2),
#  ('lovedtinafeyandamypoehleras', 2),
#  ('kristenwiigfor', 2),
#  ('andkristenwiigfor', 2),
#  ('ferrellandkristenwiigfor', 2),
#  ('willferrellandkristenwiigfor', 2),
#  ('votewillferrellandkristenwiigfor', 2),
#  ('mejores', 2),
#  ('tosee', 2),
#  ('timecantwaittosee', 2),
#  ('since ellen', 2),
#  ('andiyouruktweet', 2),
#  ('withamyandtinaas', 2),
#  ('problemwithamyandtinaas', 2),
#  ('biggestproblemwithamyandtinaas', 2),
#  ('thebiggestproblemwithamyandtinaas', 2),
#  ('was not', 2),
#  ('was not enough', 2),
#  ('was not enough amy', 2),
#  ('was not enough amy and', 2),
#  ('was not enough amy and tina', 2),
#  ('was not enough amy and tina as', 2),
#  ('was not enough amy and tina as hosts', 2),
#  ('rt::', 2),
#  ('tina fey and amy poehler arrive', 2),
#  ('tina fey and amy poehler arrive at', 2),
#  ('tina fey and amy poehler arrive at the  ceremony', 2),
#  ('tina fey and amy poehler arrive at the  ceremony by', 2),
#  ('tina fey and amy poehler arrive at the  ceremony by frederic', 2),
#  ('tina fey and amy poehler arrive at the  ceremony by frederic j', 2),
#  ('tina fey and amy poehler arrive at the  ceremony by frederic j brown', 2),
#  ('ferrellfornextyears', 2),
#  ('willferrellfornextyears', 2),
#  ('sheandtinabest', 2),
#  ('ever a look back at their friendship and', 2),
#  ('andiarenextyears', 2),
#  ('always', 2),
#  ('of all time', 2),
#  ('this', 2),
#  ('at the golden', 2),
#  ('at the golden globes', 2),
#  ('rtkristenwiigandwillferrellas', 2),
#  ('😂', 2),
#  ('😂  while my man cooks some burgers', 2),
#  (':goldenglobes', 2),
#  ('if', 2),
#  ('tinaweregreat', 2),
#  ('andtinaweregreat', 2),
#  ('globesamyandtinaweregreat', 2),
#  ('greatglobesamyandtinaweregreat', 2),
#  (' no brainer', 2),
#  (' no brainer to', 2),
#  (' no brainer to have', 2),
#  (' no brainer to have them', 2),
#  (' no brainer to have them back', 2),
#  (' no brainer to have them back next', 2),
#  (' no brainer to have them back next year', 2),
#  ('fey:best', 2),
#  ('bestawardsshow', 2),
#  (':best', 2),
#  ('rt:best', 2),
#  ('tina fey amy poehlers opening monologue is a sexual nightmare', 2),
#  ('both', 2),
#  ('carpettothe', 2),
#  ('redcarpettothe', 2),
#  ('theredcarpettothe', 2),
#  ('fromtheredcarpettothe', 2),
#  ('to the', 2),
#  ('to the show', 2),
#  ('funniest', 2),
#  ('on the', 2),
#  ('on the golden', 2),
#  ('on the golden globes', 2),
#  ('poehlerbest', 2),
#  ('amypoehlerbest', 2),
#  ('andamypoehlerbest', 2),
#  ('feyandamypoehlerbest', 2),
#  ('tinafeyandamypoehlerbest', 2),
#  ('areyouwatching', 2),
#  ('bethebest', 2),
#  ('will', 2),
#  ('after tina and amy until', 2),
#  ('alreadythebest', 2),
#  ('areamazing', 2),
#  ('for any', 2),
#  ('amy poehler and tina fey’s best bff moments -', 2),
#  ('i want', 2),
#  ('makeamazing', 2),
#  ('wouldmakeamazing', 2),
#  ('lovedthe', 2),
#  ('de todos os tempos', 2),
#  ('probablythebest', 2),
#  ('for   will you show', 2),
#  ('for   will you show  and', 2),
#  ('ever tina', 2),
#  ('-best', 2),
#  ('3timesthensurelywellbeseeingthisdynamicduoas', 2),
#  ('shoulddoayearwherethe', 2),
#  ('and all the presenters are', 2),
#  ('and congrats to all the winners', 2),
#  ('whathappenedtoyourhilarious', 2),
#  ('please', 2),
#  ('predictions:peoplewillagreeordisagreewiththechoicesthe', 2),
#  ('andasthe', 2),
#  ('amyas', 1),
#  ('andamyas', 1),
#  ('tinaandamyas', 1),
#  ('micheletinaandamyas', 1),
#  ('leamicheletinaandamyas', 1),
#  ('&amp;leamicheletinaandamyas', 1),
#  ('danes&amp;leamicheletinaandamyas', 1),
#  ('clairedanes&amp;leamicheletinaandamyas', 1),
#  ('fosterclairedanes&amp;leamicheletinaandamyas', 1),
#  ('jodiefosterclairedanes&amp;leamicheletinaandamyas', 1),
#  (':jodiefosterclairedanes&amp;leamicheletinaandamyas', 1),
#  ('rt:jodiefosterclairedanes&amp;leamicheletinaandamyas', 1),
#  ('les', 1),
#  ('les mis', 1),
#  ('les mis etc', 1),
#  ('les mis etc etc', 1),
#  ('les mis etc etc one', 1),
#  ('les mis etc etc one of', 1),
#  ('les mis etc etc one of the', 1),
#  ('les mis etc etc one of the best', 1),
#  ('les mis etc etc one of the best golden', 1),
#  ('les mis etc etc one of the best golden globes', 1),
#  ('les mis etc etc one of the best golden globes ever', 1),
#  ('phoehlerarekillingitas', 1),
#  ('amyphoehlerarekillingitas', 1),
#  ('andamyphoehlerarekillingitas', 1),
#  ('feyandamyphoehlerarekillingitas', 1),
#  ('tinafeyandamyphoehlerarekillingitas', 1),
#  ('of the golden globes dont', 1),
#  ('of the golden globes dont you', 1),
#  ('of the golden globes dont you think', 1),
#  ('of the golden globes dont you think so', 1),
#  ('laughtheyarethebest', 1),
#  ('everyonelaughtheyarethebest', 1),
#  ('makingeveryonelaughtheyarethebest', 1),
#  ('aremakingeveryonelaughtheyarethebest', 1),
#  ('tinaaremakingeveryonelaughtheyarethebest', 1),
#  ('&amp;tinaaremakingeveryonelaughtheyarethebest', 1),
#  ('amy&amp;tinaaremakingeveryonelaughtheyarethebest', 1),
#  ('for the  :)', 1),
#  ('that theyve', 1),
#  ('that theyve had', 1),
#  ('that theyve had un', 1),
#  ('that theyve had un a', 1),
#  ('that theyve had un a while', 1),
#  ('yeap', 1),
#  ('yeap definitely', 1),
#  ('ever just', 1),
#  ('ever just sayin', 1),
#  ('poehlerandtinafeyarethebest', 1),
#  ('amypoehlerandtinafeyarethebest', 1),
#  ('poehlerasthe', 1),
#  ('amypoehlerasthe', 1),
#  ('andamypoehlerasthe', 1),
#  ('feyandamypoehlerasthe', 1),
#  ('tinafeyandamypoehlerasthe', 1),
#  ('fortinafeyandamypoehlerasthe', 1),
#  ('expectationsfortinafeyandamypoehlerasthe', 1),
#  ('highexpectationsfortinafeyandamypoehlerasthe', 1),
#  ('toohighexpectationsfortinafeyandamypoehlerasthe', 1),
#  ('havetoohighexpectationsfortinafeyandamypoehlerasthe', 1),
#  ('justhavetoohighexpectationsfortinafeyandamypoehlerasthe', 1),
#  ('wejusthavetoohighexpectationsfortinafeyandamypoehlerasthe', 1),
#  ('guesswejusthavetoohighexpectationsfortinafeyandamypoehlerasthe', 1),
#  ('iguesswejusthavetoohighexpectationsfortinafeyandamypoehlerasthe', 1),
#  ('ahahahahahahnextyears', 1),
#  (' &amp;  stealing', 1),
#  (' &amp;  stealing the', 1),
#  (' &amp;  stealing the show', 1),
#  (' &amp;  stealing the show :)', 1),
#  ('shouldbethe', 1),
#  ('poehlershouldbethe', 1),
#  ('amypoehlershouldbethe', 1),
#  ('&amp;amypoehlershouldbethe', 1),
#  ('fey&amp;amypoehlershouldbethe', 1),
#  ('tinafey&amp;amypoehlershouldbethe', 1),
#  (':tinafey&amp;amypoehlershouldbethe', 1),
#  ('rt:tinafey&amp;amypoehlershouldbethe', 1),
#  ('of everything all', 1),
#  ('of everything all the', 1),
#  ('of everything all the time', 1),
#  ('beatthe', 1),
#  ('shebeatthe', 1),
#  ('ifshebeatthe', 1),
#  ('funnyifshebeatthe', 1),
#  ('befunnyifshebeatthe', 1),
#  ('betterbefunnyifshebeatthe', 1),
#  ('girlbetterbefunnyifshebeatthe', 1),
#  ('thisgirlbetterbefunnyifshebeatthe', 1),
#  ('butthisgirlbetterbefunnyifshebeatthe', 1),
#  ('nobutthisgirlbetterbefunnyifshebeatthe', 1),
#  ('girlsnobutthisgirlbetterbefunnyifshebeatthe', 1),
#  ('seengirlsnobutthisgirlbetterbefunnyifshebeatthe', 1),
#  ('iseengirlsnobutthisgirlbetterbefunnyifshebeatthe', 1),
#  ('haveiseengirlsnobutthisgirlbetterbefunnyifshebeatthe', 1),
#  (':haveiseengirlsnobutthisgirlbetterbefunnyifshebeatthe', 1),
#  ('rt:haveiseengirlsnobutthisgirlbetterbefunnyifshebeatthe', 1),
#  ('fucking', 1),
#  ('thefucking', 1),
#  ('asthefucking', 1),
#  ('disappearanceasthefucking', 1),
#  ('bestdisappearanceasthefucking', 1),
#  ('forbestdisappearanceasthefucking', 1),
#  ('globeforbestdisappearanceasthefucking', 1),
#  ('goldenglobeforbestdisappearanceasthefucking', 1),
#  ('thegoldenglobeforbestdisappearanceasthefucking', 1),
#  ('awardedthegoldenglobeforbestdisappearanceasthefucking', 1),
#  ('beenawardedthegoldenglobeforbestdisappearanceasthefucking', 1),
#  ('havebeenawardedthegoldenglobeforbestdisappearanceasthefucking', 1),
#  ('poehlerhavebeenawardedthegoldenglobeforbestdisappearanceasthefucking', 1),
#  ('amypoehlerhavebeenawardedthegoldenglobeforbestdisappearanceasthefucking',
#   1),
#  ('andamypoehlerhavebeenawardedthegoldenglobeforbestdisappearanceasthefucking',
#   1),
#  ('feyandamypoehlerhavebeenawardedthegoldenglobeforbestdisappearanceasthefucking',
#   1),
#  ('tinafeyandamypoehlerhavebeenawardedthegoldenglobeforbestdisappearanceasthefucking',
#   1),
#  (':tinafeyandamypoehlerhavebeenawardedthegoldenglobeforbestdisappearanceasthefucking',
#   1),
#  ('rt:tinafeyandamypoehlerhavebeenawardedthegoldenglobeforbestdisappearanceasthefucking',
#   1),
#  ('beatamyandtinaas', 1),
#  ('honestlybeatamyandtinaas', 1),
#  ('canhonestlybeatamyandtinaas', 1),
#  ('whocanhonestlybeatamyandtinaas', 1),
#  ('seriouslywhocanhonestlybeatamyandtinaas', 1),
#  (':seriouslywhocanhonestlybeatamyandtinaas', 1),
#  ('rt:seriouslywhocanhonestlybeatamyandtinaas', 1),
#  (' no one', 1),
#  (' no one thats', 1),
#  (' no one thats who', 1),
#  ('tinaarekillingitas', 1),
#  ('andtinaarekillingitas', 1),
#  ('amyandtinaarekillingitas', 1),
#  ('right now', 1),
#  ('thewomen', 1),
#  ('thatthewomen', 1),
#  ('coincidencethatthewomen', 1),
#  ('nocoincidencethatthewomen', 1),
#  (':nocoincidencethatthewomen', 1),
#  ('rt:nocoincidencethatthewomen', 1),
#  ('ended', 1),
#  ('ended the', 1),
#  ('ended the show', 1),
#  ('ended the show on', 1),
#  ('ended the show on time', 1),
#  ('ended the show on time just', 1),
#  ('ended the show on time just saying', 1),
#  ('ever at', 1),
#  ('ever at the', 1),
#  ('ever at the golden', 1),
#  ('ever at the golden globes', 1),
#  ('weseethe', 1),
#  ('littleweseethe', 1),
#  ('howlittleweseethe', 1),
#  ('nutshowlittleweseethe', 1),
#  ('menutshowlittleweseethe', 1),
#  ('drivesmenutshowlittleweseethe', 1),
#  ('itdrivesmenutshowlittleweseethe', 1),
#  (':itdrivesmenutshowlittleweseethe', 1),
#  ('rt:itdrivesmenutshowlittleweseethe', 1),
#  ('during', 1),
#  ('during this', 1),
#  ('during this show', 1),
#  ('during this show especially', 1),
#  ('during this show especially with', 1),
#  ('during this show especially with them', 1),
#  ('during this show especially with them being', 1),
#  ('during this show especially with them being as', 1),
#  ('during this show especially with them being as awesome', 1),
#  ('during this show especially with them being as awesome as', 1),
#  ('during this show especially with them being as awesome as they', 1),
#  ('during this show especially with them being as awesome as they are', 1),
#  ('female', 1),
#  ('firstfemale', 1),
#  ('historyfirstfemale', 1),
#  ('makinghistoryfirstfemale', 1),
#  ('aremakinghistoryfirstfemale', 1),
#  ('ladiesaremakinghistoryfirstfemale', 1),
#  ('theseladiesaremakinghistoryfirstfemale', 1),
#  (':theseladiesaremakinghistoryfirstfemale', 1),
#  ('rt:theseladiesaremakinghistoryfirstfemale', 1),
#  ('didthe', 1),
#  ('rightdidthe', 1),
#  ('friendisrightdidthe', 1),
#  ('myfriendisrightdidthe', 1),
#  ('go', 1),
#  ('go for', 1),
#  ('go for a', 1),
#  ('go for a smoke', 1),
#  ('go for a smoke at', 1),
#  ('go for a smoke at a', 1),
#  ('go for a smoke at a commercial', 1),
#  ('go for a smoke at a commercial break', 1),
#  ('go for a smoke at a commercial break &amp;', 1),
#  ('go for a smoke at a commercial break &amp; get', 1),
#  ('go for a smoke at a commercial break &amp; get locked', 1),
#  ('go for a smoke at a commercial break &amp; get locked out', 1),
#  ('happenedtothe', 1),
#  ('whathappenedtothe', 1),
#  ('of this', 1),
#  ('of this show', 1),
#  ('entertainingifthe', 1),
#  ('moreentertainingifthe', 1),
#  ('lotmoreentertainingifthe', 1),
#  ('alotmoreentertainingifthe', 1),
#  ('bealotmoreentertainingifthe', 1),
#  ('thewouldbealotmoreentertainingifthe', 1),
#  ('(tina', 1),
#  ('(tina and', 1),
#  ('(tina and amy)', 1),
#  ('(tina and amy) would', 1),
#  ('(tina and amy) would make', 1),
#  ('(tina and amy) would make more', 1),
#  ('(tina and amy) would make more of', 1),
#  ('(tina and amy) would make more of an', 1),
#  ('(tina and amy) would make more of an appearance', 1),
#  ('of the :', 1),
#  ('of the : tina', 1),
#  ('of the : tina fey', 1),
#  ('of the : tina fey ()', 1),
#  ('of the : tina fey () and', 1),
#  ('of the : tina fey () and amy', 1),
#  ('of the : tina fey () and amy poehler', 1),
#  ('of the : tina fey () and amy poehler ()', 1),
#  ('of the : tina fey () and amy poehler () --', 1),
#  ('of the : tina fey () and amy poehler () -- theyre', 1),
#  ('of the : tina fey () and amy poehler () -- theyre very', 1),
#  ('of the : tina fey () and amy poehler () -- theyre very compatible', 1),
#  ('of the : tina fey () and amy poehler () -- theyre very compatible so', 1),
#  ('of the : tina fey () and amy poehler () -- theyre very compatible so expect',
#   1),
#  ('of the : tina fey () and amy poehler () -- theyre very compatible so expect a',
#   1),
#  ('of the : tina fey () and amy poehler () -- theyre very compatible so expect a good',
#   1),
#  ('of the : tina fey () and amy poehler () -- theyre very compatible so expect a good show',
#   1),
#  ('ever they', 1),
#  ('ever they should', 1),
#  ('ever they should host', 1),
#  ('ever they should host everything', 1),
#  ('ever they should host everything imagine', 1),
#  ('ever they should host everything imagine the', 1),
#  ('ever they should host everything imagine the possibilities', 1),
#  ('whenthe', 1),
#  ('rememberwhenthe', 1),
#  ('not the', 1),
#  ('not the voiceover', 1),
#  ('not the voiceover guy', 1),
#  ('not the voiceover guy hosted', 1),
#  ('not the voiceover guy hosted the', 1),
#  ('not the voiceover guy hosted the show', 1),
#  ('poehlerkillingitas', 1),
#  ('amypoehlerkillingitas', 1),
#  ('andamypoehlerkillingitas', 1),
#  ('feyandamypoehlerkillingitas', 1),
#  ('tinafeyandamypoehlerkillingitas', 1),
#  (':tinafeyandamypoehlerkillingitas', 1),
#  ('rt:tinafeyandamypoehlerkillingitas', 1),
#  ('boss', 1),
#  ('boss ladies', 1),
#  ('inthe', 1),
#  ('disappointedinthe', 1),
#  ('imdisappointedinthe', 1),
#  ('farimdisappointedinthe', 1),
#  ('sofarimdisappointedinthe', 1),
#  ('or lack', 1),
#  ('or lack thereof', 1),
#  ('tina fey amy poehlers opening monologue is a sexual nightmare: \njames cameron ://',
#   1),
#  ('benextyears', 1),
#  ('tobenextyears', 1),
#  ('votetobenextyears', 1),
#  ('ourvotetobenextyears', 1),
#  ('haveourvotetobenextyears', 1),
#  ('ferrellhaveourvotetobenextyears', 1),
#  ('willferrellhaveourvotetobenextyears', 1),
#  ('andwillferrellhaveourvotetobenextyears', 1),
#  ('wiigandwillferrellhaveourvotetobenextyears', 1),
#  ('kristenwiigandwillferrellhaveourvotetobenextyears', 1),
#  (':kristenwiigandwillferrellhaveourvotetobenextyears', 1),
#  ('rt:kristenwiigandwillferrellhaveourvotetobenextyears', 1),
#  ('ferrell-nextyears', 1),
#  ('willferrell-nextyears', 1),
#  ('andwillferrell-nextyears', 1),
#  ('wiigandwillferrell-nextyears', 1),
#  ('kristenwiigandwillferrell-nextyears', 1),
#  (':kristenwiigandwillferrell-nextyears', 1),
#  ('rt:kristenwiigandwillferrell-nextyears', 1),
#  ('crying', 1),
#  ('crying im', 1),
#  ('crying im laughing', 1),
#  ('crying im laughing so', 1),
#  ('crying im laughing so hard', 1),
#  ('&amp;especiallyas', 1),
#  ('amy&amp;especiallyas', 1),
#  ('loveamy&amp;especiallyas', 1),
#  ('iloveamy&amp;especiallyas', 1),
#  ('cause', 1),
#  ('cause they', 1),
#  ('cause they need', 1),
#  ('cause they need to', 1),
#  ('cause they need to some', 1),
#  ('cause they need to some what', 1),
#  ('cause they need to some what behave', 1),
#  ('cause they need to some what behave makes', 1),
#  ('cause they need to some what behave makes it', 1),
#  ('cause they need to some what behave makes it even', 1),
#  ('cause they need to some what behave makes it even funnier', 1),
#  ('tina fey amy poehlers opening monologue is a sexual nightmare: \njames cameron is',
#   1),
#  ('tina fey amy poehlers opening monologue is a sexual nightmare: \njames cameron is the',
#   1),
#  ('tina fey amy poehlers opening monologue is a sexual nightmare: \njames cameron is the source',
#   1),
#  ('tina fey amy poehlers opening monologue is a sexual nightmare: \njames cameron is the source of',
#   1),
#  ('tina fey amy poehlers opening monologue is a sexual nightmare: \njames cameron is the source of much',
#   1),
#  ('\nbest', 1),
#  ('😂😂\n\nbest', 1),
#  ('now😂😂\n\nbest', 1),
#  ('rightnow😂😂\n\nbest', 1),
#  ('uprightnow😂😂\n\nbest', 1),
#  ('meuprightnow😂😂\n\nbest', 1),
#  ('crackingmeuprightnow😂😂\n\nbest', 1),
#  ('arecrackingmeuprightnow😂😂\n\nbest', 1),
#  ('feyarecrackingmeuprightnow😂😂\n\nbest', 1),
#  ('tinafeyarecrackingmeuprightnow😂😂\n\nbest', 1),
#  ('andtinafeyarecrackingmeuprightnow😂😂\n\nbest', 1),
#  ('poehlerandtinafeyarecrackingmeuprightnow😂😂\n\nbest', 1),
#  ('amypoehlerandtinafeyarecrackingmeuprightnow😂😂\n\nbest', 1),
#  ('the golden globes have had', 1),
#  ('the golden globes have had in', 1),
#  ('the golden globes have had in a', 1),
#  ('the golden globes have had in a while', 1),
#  ('are great', 1),
#  ('are great great', 1),
#  ('are great great humor', 1),
#  ('are great great humor and', 1),
#  ('are great great humor and fun', 1),
#  ('permanent', 1),
#  ('namedpermanent', 1),
#  ('benamedpermanent', 1),
#  ('justbenamedpermanent', 1),
#  ('poehlerjustbenamedpermanent', 1),
#  ('amypoehlerjustbenamedpermanent', 1),
#  ('andamypoehlerjustbenamedpermanent', 1),
#  ('feyandamypoehlerjustbenamedpermanent', 1),
#  ('tinafeyandamypoehlerjustbenamedpermanent', 1),
#  ('cantinafeyandamypoehlerjustbenamedpermanent', 1),
#  ('of the golden globes already', 1),
#  ('ferrell/wiigforgoldenglobes', 1),
#  (':ferrell/wiigforgoldenglobes', 1),
#  ('rt:ferrell/wiigforgoldenglobes', 1),
#  ('2014 poehler/fey', 1),
#  ('2014 poehler/fey for', 1),
#  ('2014 poehler/fey for president', 1),
#  ('2014 poehler/fey for president 2016', 1),
#  ('the golden globes: a host of stars are attending the golden globes in hollywood with maggie smith',
#   1),
#  ('the golden globes: a host of stars are attending the golden globes in hollywood with maggie smith and',
#   1),
#  ('the golden globes: a host of stars are attending the golden globes in hollywood with maggie smith and homeland',
#   1),
#  ('farthebest', 1),
#  ('byfarthebest', 1),
#  ('arebyfarthebest', 1),
#  ('poehlerarebyfarthebest', 1),
#  ('amypoehlerarebyfarthebest', 1),
#  ('andamypoehlerarebyfarthebest', 1),
#  ('feyandamypoehlerarebyfarthebest', 1),
#  ('tinafeyandamypoehlerarebyfarthebest', 1),
#  ('jobbest', 1),
#  ('amazingjobbest', 1),
#  ('anamazingjobbest', 1),
#  (':anddidanamazingjobbest', 1),
#  ('rt:anddidanamazingjobbest', 1),
#  ('the golden globes |', 1),
#  ('the golden globes | via', 1),
#  ('the golden globes | via bbc', 1),
#  ('the golden globes | via bbc world', 1),
#  ('the golden globes | via bbc world news', 1),
#  ('howthe', 1),
#  ('lovehowthe', 1),
#  ('are talking', 1),
#  ('are talking and', 1),
#  ('are talking and you', 1),
#  ('are talking and you hear', 1),
#  ('are talking and you hear the', 1),
#  ('are talking and you hear the tv', 1),
#  ('are talking and you hear the tv crew', 1),
#  ('are talking and you hear the tv crew counting', 1),
#  ('are talking and you hear the tv crew counting them', 1),
#  ('are talking and you hear the tv crew counting them out', 1),
#  ('favoriteawardshow', 1),
#  ('myfavoriteawardshow', 1),
#  ('alreadymyfavoriteawardshow', 1),
#  ('arealreadymyfavoriteawardshow', 1),
#  ('tinaarealreadymyfavoriteawardshow', 1),
#  ('andtinaarealreadymyfavoriteawardshow', 1),
#  ('amyandtinaarealreadymyfavoriteawardshow', 1),
#  (':amyandtinaarealreadymyfavoriteawardshow', 1),
#  ('rt:amyandtinaarealreadymyfavoriteawardshow', 1),
#  ('for next year will', 1),
#  ('for next year will ferrel', 1),
#  ('for next year will ferrel and', 1),
#  ('for next year will ferrel and kristen', 1),
#  ('for next year will ferrel and kristen wig', 1),
#  ('for next year will ferrel and kristen wig hilarious', 1),
#  ('for next year will ferrel and kristen wig hilarious duo', 1),
#  ('loving&amp;asfunny', 1),
#  ('be', 1),
#  ('ferrellbe', 1),
#  ('willferrellbe', 1),
#  ('andwillferrellbe', 1),
#  ('wiigandwillferrellbe', 1),
#  ('kristenwiigandwillferrellbe', 1),
#  ('cankristenwiigandwillferrellbe', 1),
#  ('for next year the', 1),
#  ('for next year the people', 1),
#  ('for next year the people demand', 1),
#  ('for next year the people demand it', 1),
#  ('andthe', 1),
#  ('uglyandthe', 1),
#  ('areuglyandthe', 1),
#  ('menareuglyandthe', 1),
#  ('themenareuglyandthe', 1),
#  ('andthemenareuglyandthe', 1),
#  ('uglyandthemenareuglyandthe', 1),
#  ('areuglyandthemenareuglyandthe', 1),
#  ('womenareuglyandthemenareuglyandthe', 1),
#  ('thewomenareuglyandthemenareuglyandthe', 1),
#  ('allthewomenareuglyandthemenareuglyandthe', 1),
#  (':allthewomenareuglyandthemenareuglyandthe', 1),
#  ('rt:allthewomenareuglyandthemenareuglyandthe', 1),
#  ('are ugly', 1),
#  ('are ugly and', 1),
#  ('are ugly and the', 1),
#  ('are ugly and the culture', 1),
#  ('are ugly and the culture is', 1),
#  ('are ugly and the culture is ugly', 1),
#  ('are ugly and the culture is ugly and', 1),
#  ('are ugly and the culture is ugly and the', 1),
#  ('are ugly and the culture is ugly and the films', 1),
#  ('are ugly and the culture is ugly and the films are', 1),
#  ('are ugly and the culture is ugly and the films are ugly', 1),
#  ('are ugly and the culture is ugly and the films are ugly and', 1),
#  ('are ugly and the culture is ugly and the films are ugly and the', 1),
#  ('are ugly and the culture is ugly and the films are ugly and the mach', 1),
#  ('of all time:', 1),
#  ('of all time: standing', 1),
#  ('of all time: standing ovation', 1),
#  ('of all time: standing ovation \nyes', 1),
#  ('of all time: standing ovation \nyes yes', 1),
#  ('of all time: standing ovation \nyes yes ://', 1),
#  ('fuckinggood', 1),
#  ('befuckinggood', 1),
#  ('betterbefuckinggood', 1),
#  ('bothbetterbefuckinggood', 1),
#  ('youbothbetterbefuckinggood', 1),
#  ('feyyoubothbetterbefuckinggood', 1),
#  ('tinafeyyoubothbetterbefuckinggood', 1),
#  ('andtinafeyyoubothbetterbefuckinggood', 1),
#  ('poehlerandtinafeyyoubothbetterbefuckinggood', 1),
#  ('amypoehlerandtinafeyyoubothbetterbefuckinggood', 1),
#  ('because', 1),
#  ('because im', 1),
#  ('because im watching', 1),
#  ('because im watching this', 1),
#  ('because im watching this garbage', 1),
#  ('accordingtothe', 1),
#  ('filmaccordingtothe', 1),
#  ('infilmaccordingtothe', 1),
#  ('womeninfilmaccordingtothe', 1),
#  ('forwomeninfilmaccordingtothe', 1),
#  ('yearforwomeninfilmaccordingtothe', 1),
#  ('greatyearforwomeninfilmaccordingtothe', 1),
#  ('agreatyearforwomeninfilmaccordingtothe', 1),
#  ('itsagreatyearforwomeninfilmaccordingtothe', 1),
#  ('fact:itsagreatyearforwomeninfilmaccordingtothe', 1),
#  (':fact:itsagreatyearforwomeninfilmaccordingtothe', 1),
#  ('rt:fact:itsagreatyearforwomeninfilmaccordingtothe', 1),
#  ('amy poehler and tina fey', 1),
#  ('them', 1),
#  ('callingthem', 1),
#  ('was such', 1),
#  ('was such a', 1),
#  ('was such a tease', 1),
#  ('was such a tease hfp', 1),
#  ('was such a tease hfp totally', 1),
#  ('was such a tease hfp totally underutilized', 1),
#  ('we saw', 1),
#  ('we saw more', 1),
#  ('we saw more of', 1),
#  ('we saw more of tina', 1),
#  ('we saw more of tina and', 1),
#  ('we saw more of tina and amy', 1),
#  ('we saw more of tina and amy in', 1),
#  ('we saw more of tina and amy in the', 1),
#  ('we saw more of tina and amy in the promos', 1),
#  ('we saw more of tina and amy in the promos for', 1),
#  ('we saw more of tina and amy in the promos for the', 1),
#  ('we saw more of tina and amy in the promos for the show', 1),
#  ('ferrell/kristenwiig', 1),
#  ('willferrell/kristenwiig', 1),
#  (':willferrell/kristenwiig', 1),
#  ('rt:willferrell/kristenwiig', 1),
#  ('poelerarekillingitas', 1),
#  ('amypoelerarekillingitas', 1),
#  ('andamypoelerarekillingitas', 1),
#  ('feyandamypoelerarekillingitas', 1),
#  ('tinafeyandamypoelerarekillingitas', 1),
#  ('so hilarious', 1),
#  ('this“:willferrellandkristenwiig', 1),
#  ('likethis“:willferrellandkristenwiig', 1),
#  ('justlikethis“:willferrellandkristenwiig', 1),
#  ('&amp;werethebest', 1),
#  ('wiig:', 1),
#  ('kristenwiig:', 1),
#  ('&amp;kristenwiig:', 1),
#  ('ferrell&amp;kristenwiig:', 1),
#  ('willferrell&amp;kristenwiig:', 1),
#  (':willferrell&amp;kristenwiig:', 1),
#  ('rt:willferrell&amp;kristenwiig:', 1),
#  ('for golden', 1),
#  ('for golden globes', 1),
#  ('for golden globes 2014  ~m', 1),
#  ('rtbringthe', 1),
#  ('thisrtbringthe', 1),
#  ...]
